# %%
import os
import pandas as pd
from PIL import Image
from transformers import AutoImageProcessor, AutoModelForImageClassification, Trainer, TrainingArguments
from datasets import Dataset
import evaluate
import torch
from sklearn.model_selection import train_test_split
import numpy as np

# %%
# Пути к директориям с данными
train_dir = "train/simpsons_dataset"
test_dir = "testset/testset"

# %%
# Получение списка классов из директории обучения
characters = sorted(os.listdir(train_dir))
num_classes = len(characters)
character_labels = {character: idx for idx, character in enumerate(characters)}

# %%
num_classes
# Out:
# 42

# %%
character_labels
# Out:
# {'abraham_grampa_simpson': 0,
#  'agnes_skinner': 1,
#  'apu_nahasapeemapetilon': 2,
#  'barney_gumble': 3,
#  'bart_simpson': 4,
#  'carl_carlson': 5,
#  'charles_montgomery_burns': 6,
#  'chief_wiggum': 7,
#  'cletus_spuckler': 8,
#  'comic_book_guy': 9,
#  'disco_stu': 10,
#  'edna_krabappel': 11,
#  'fat_tony': 12,
#  'gil': 13,
#  'groundskeeper_willie': 14,
#  'homer_simpson': 15,
#  'kent_brockman': 16,
#  'krusty_the_clown': 17,
#  'lenny_leonard': 18,
#  'lionel_hutz': 19,
#  'lisa_simpson': 20,
#  'maggie_simpson': 21,
#  'marge_simpson': 22,
#  'martin_prince': 23,
#  'mayor_quimby': 24,
#  'milhouse_van_houten': 25,
#  'miss_hoover': 26,
#  'moe_szyslak': 27,
#  'ned_flanders': 28,
#  'nelson_muntz': 29,
#  'otto_mann': 30,
#  'patty_bouvier': 31,
#  'principal_skinner': 32,
#  'professor_john_frink': 33,
#  'rainier_wolfcastle': 34,
#  'ralph_wiggum': 35,
#  'selma_bouvier': 36,
#  'sideshow_bob': 37,
#  'sideshow_mel': 38,
#  'snake_jailbird': 39,
#  'troy_mcclure': 40,
#  'waylon_smithers': 41}

# %%
# Подготовка данных для тренировочного набора
train_data = []
for character in characters:
    character_folder = os.path.join(train_dir, character)
    for img_name in os.listdir(character_folder):
        img_path = os.path.join(character_folder, img_name)
        train_data.append({"image_path": img_path, "label": character_labels[character]})

# Подготовка данных для тестового набора
test_data = []
for img_name in os.listdir(test_dir):
    img_path = os.path.join(test_dir, img_name)
    image_id = os.path.splitext(img_name)[0]
    test_data.append({"image_path": img_path, "image_id": image_id})

# %%
train_data
# Out:
# [{'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0000.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0001.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0002.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0003.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0004.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0005.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0006.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0007.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0008.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0009.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0010.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0011.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0012.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0013.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0014.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0015.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0016.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0017.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0018.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0019.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0020.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0021.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0022.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0023.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0024.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0025.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0026.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0027.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0028.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0029.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0030.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0031.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0032.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0033.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0034.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0035.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0036.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0037.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0038.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0039.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0040.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0041.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0042.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0043.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0044.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0045.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0046.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0047.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0048.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0049.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0050.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0051.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0052.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0053.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0054.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0055.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0056.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0057.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0058.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0059.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0060.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0061.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0062.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0063.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0064.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0065.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0066.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0067.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0068.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0069.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0070.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0071.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0072.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0073.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0074.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0075.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0076.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0077.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0078.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0079.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0080.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0081.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0082.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0083.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0084.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0085.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0086.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0087.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0088.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0089.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0090.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0091.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0092.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0093.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0094.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0095.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0096.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0097.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0098.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0099.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0100.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0101.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0102.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0103.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0104.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0105.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0106.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0107.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0108.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0109.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0110.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0111.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0112.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0113.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0114.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0115.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0116.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0117.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0118.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0119.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0120.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0121.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0122.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0123.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0124.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0125.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0126.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0127.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0128.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0129.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0130.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0131.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0132.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0133.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0134.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0135.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0136.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0137.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0138.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0139.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0140.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0141.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0142.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0143.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0144.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0145.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0146.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0147.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0148.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0149.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0150.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0151.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0152.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0153.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0154.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0155.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0156.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0157.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0158.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0159.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0160.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0161.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0162.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0163.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0164.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0165.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0166.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0167.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0168.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0169.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0170.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0171.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0172.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0173.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0174.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0175.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0176.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0177.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0178.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0179.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0180.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0181.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0182.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0183.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0184.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0185.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0186.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0187.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0188.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0189.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0190.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0191.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0192.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0193.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0194.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0195.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0196.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0197.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0198.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0199.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0200.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0201.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0202.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0203.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0204.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0205.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0206.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0207.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0208.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0209.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0210.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0211.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0212.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0213.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0214.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0215.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0216.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0217.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0218.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0219.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0220.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0221.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0222.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0223.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0224.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0225.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0226.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0227.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0228.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0229.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0230.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0231.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0232.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0233.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0234.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0235.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0236.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0237.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0238.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0239.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0240.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0241.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0242.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0243.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0244.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0245.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0246.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0247.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0248.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0249.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0250.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0251.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0252.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0253.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0254.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0255.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0256.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0257.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0258.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0259.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0260.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0261.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0262.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0263.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0264.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0265.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0266.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0267.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0268.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0269.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0270.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0271.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0272.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0273.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0274.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0275.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0276.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0277.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0278.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0279.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0280.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0281.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0282.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0283.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0284.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0285.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0286.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0287.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0288.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0289.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0290.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0291.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0292.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0293.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0294.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0295.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0296.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0297.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0298.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0299.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0300.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0301.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0302.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0303.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0304.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0305.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0306.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0307.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0308.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0309.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0310.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0311.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0312.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0313.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0314.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0315.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0316.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0317.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0318.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0319.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0320.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0321.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0322.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0323.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0324.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0325.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0326.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0327.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0328.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0329.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0330.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0331.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0332.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0333.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0334.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0335.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0336.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0337.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0338.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0339.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0340.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0341.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0342.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0343.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0344.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0345.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0346.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0347.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0348.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0349.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0350.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0351.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0352.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0353.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0354.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0355.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0356.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0357.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0358.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0359.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0360.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0361.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0362.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0363.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0364.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0365.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0366.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0367.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0368.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0369.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0370.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0371.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0372.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0373.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0374.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0375.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0376.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0377.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0378.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0379.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0380.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0381.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0382.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0383.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0384.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0385.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0386.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0387.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0388.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0389.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0390.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0391.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0392.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0393.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0394.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0395.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0396.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0397.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0398.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0399.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0400.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0401.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0402.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0403.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0404.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0405.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0406.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0407.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0408.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0409.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0410.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0411.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0412.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0413.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0414.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0415.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0416.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0417.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0418.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0419.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0420.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0421.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0422.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0423.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0424.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0425.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0426.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0427.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0428.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0429.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0430.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0431.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0432.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0433.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0434.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0435.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0436.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0437.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0438.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0439.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0440.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0441.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0442.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0443.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0444.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0445.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0446.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0447.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0448.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0449.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0450.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0451.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0452.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0453.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0454.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0455.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0456.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0457.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0458.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0459.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0460.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0461.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0462.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0463.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0464.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0465.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0466.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0467.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0468.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0469.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0470.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0471.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0472.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0473.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0474.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0475.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0476.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0477.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0478.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0479.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0480.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0481.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0482.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0483.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0484.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0485.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0486.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0487.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0488.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0489.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0490.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0491.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0492.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0493.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0494.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0495.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0496.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0497.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0498.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0499.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0500.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0501.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0502.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0503.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0504.jpg',
#   'label': 0},
# ...
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0828.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0829.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0830.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0831.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0832.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0833.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0834.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0835.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0836.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0837.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0838.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0839.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0840.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0841.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0842.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0843.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0844.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0845.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0846.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0847.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0848.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0849.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0850.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0851.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0852.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0853.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0854.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0855.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0856.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0857.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0858.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0859.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0860.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0861.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0862.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0863.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0864.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0865.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0866.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0867.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0868.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0869.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0870.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0871.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0872.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0873.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0874.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0875.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0876.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0877.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0878.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0879.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0880.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0881.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0882.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0883.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0884.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0885.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0886.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0887.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0888.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0889.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0890.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0891.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0892.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0893.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0894.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0895.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0896.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0897.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0898.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0899.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0900.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0901.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0902.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0903.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0904.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0905.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0906.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0907.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0908.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0909.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0910.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0911.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\abraham_grampa_simpson\\pic_0912.jpg',
#   'label': 0},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0000.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0001.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0002.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0003.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0004.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0005.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0006.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0007.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0008.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0009.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0010.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0011.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0012.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0013.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0014.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0015.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0016.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0017.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0018.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0019.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0020.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0021.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0022.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0023.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0024.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0025.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0026.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0027.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0028.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0029.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0030.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0031.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0032.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0033.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0034.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0035.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0036.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0037.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0038.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0039.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0040.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\agnes_skinner\\pic_0041.jpg',
#   'label': 1},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0000.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0001.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0002.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0003.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0004.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0005.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0006.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0007.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0008.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0009.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0010.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0011.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0012.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0013.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0014.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0015.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0016.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0017.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0018.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0019.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0020.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0021.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0022.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0023.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0024.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0025.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0026.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0027.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0028.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0029.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0030.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0031.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0032.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0033.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0034.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0035.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0036.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0037.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0038.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0039.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0040.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0041.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0042.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0043.jpg',
#   'label': 2},
#  {'image_path': 'train/simpsons_dataset\\apu_nahasapeemapetilon\\pic_0044.jpg',
#   'label': 2},
#  ...]

# %%
test_data
# Out:
# [{'image_path': 'testset/testset\\img0.jpg', 'image_id': 'img0'},
#  {'image_path': 'testset/testset\\img1.jpg', 'image_id': 'img1'},
#  {'image_path': 'testset/testset\\img10.jpg', 'image_id': 'img10'},
#  {'image_path': 'testset/testset\\img100.jpg', 'image_id': 'img100'},
#  {'image_path': 'testset/testset\\img101.jpg', 'image_id': 'img101'},
#  {'image_path': 'testset/testset\\img102.jpg', 'image_id': 'img102'},
#  {'image_path': 'testset/testset\\img103.jpg', 'image_id': 'img103'},
#  {'image_path': 'testset/testset\\img104.jpg', 'image_id': 'img104'},
#  {'image_path': 'testset/testset\\img105.jpg', 'image_id': 'img105'},
#  {'image_path': 'testset/testset\\img106.jpg', 'image_id': 'img106'},
#  {'image_path': 'testset/testset\\img107.jpg', 'image_id': 'img107'},
#  {'image_path': 'testset/testset\\img108.jpg', 'image_id': 'img108'},
#  {'image_path': 'testset/testset\\img109.jpg', 'image_id': 'img109'},
#  {'image_path': 'testset/testset\\img11.jpg', 'image_id': 'img11'},
#  {'image_path': 'testset/testset\\img110.jpg', 'image_id': 'img110'},
#  {'image_path': 'testset/testset\\img111.jpg', 'image_id': 'img111'},
#  {'image_path': 'testset/testset\\img112.jpg', 'image_id': 'img112'},
#  {'image_path': 'testset/testset\\img113.jpg', 'image_id': 'img113'},
#  {'image_path': 'testset/testset\\img114.jpg', 'image_id': 'img114'},
#  {'image_path': 'testset/testset\\img115.jpg', 'image_id': 'img115'},
#  {'image_path': 'testset/testset\\img116.jpg', 'image_id': 'img116'},
#  {'image_path': 'testset/testset\\img117.jpg', 'image_id': 'img117'},
#  {'image_path': 'testset/testset\\img118.jpg', 'image_id': 'img118'},
#  {'image_path': 'testset/testset\\img119.jpg', 'image_id': 'img119'},
#  {'image_path': 'testset/testset\\img12.jpg', 'image_id': 'img12'},
#  {'image_path': 'testset/testset\\img120.jpg', 'image_id': 'img120'},
#  {'image_path': 'testset/testset\\img121.jpg', 'image_id': 'img121'},
#  {'image_path': 'testset/testset\\img122.jpg', 'image_id': 'img122'},
#  {'image_path': 'testset/testset\\img123.jpg', 'image_id': 'img123'},
#  {'image_path': 'testset/testset\\img124.jpg', 'image_id': 'img124'},
#  {'image_path': 'testset/testset\\img125.jpg', 'image_id': 'img125'},
#  {'image_path': 'testset/testset\\img126.jpg', 'image_id': 'img126'},
#  {'image_path': 'testset/testset\\img127.jpg', 'image_id': 'img127'},
#  {'image_path': 'testset/testset\\img128.jpg', 'image_id': 'img128'},
#  {'image_path': 'testset/testset\\img129.jpg', 'image_id': 'img129'},
#  {'image_path': 'testset/testset\\img13.jpg', 'image_id': 'img13'},
#  {'image_path': 'testset/testset\\img130.jpg', 'image_id': 'img130'},
#  {'image_path': 'testset/testset\\img131.jpg', 'image_id': 'img131'},
#  {'image_path': 'testset/testset\\img132.jpg', 'image_id': 'img132'},
#  {'image_path': 'testset/testset\\img133.jpg', 'image_id': 'img133'},
#  {'image_path': 'testset/testset\\img134.jpg', 'image_id': 'img134'},
#  {'image_path': 'testset/testset\\img135.jpg', 'image_id': 'img135'},
#  {'image_path': 'testset/testset\\img136.jpg', 'image_id': 'img136'},
#  {'image_path': 'testset/testset\\img137.jpg', 'image_id': 'img137'},
#  {'image_path': 'testset/testset\\img138.jpg', 'image_id': 'img138'},
#  {'image_path': 'testset/testset\\img139.jpg', 'image_id': 'img139'},
#  {'image_path': 'testset/testset\\img14.jpg', 'image_id': 'img14'},
#  {'image_path': 'testset/testset\\img140.jpg', 'image_id': 'img140'},
#  {'image_path': 'testset/testset\\img141.jpg', 'image_id': 'img141'},
#  {'image_path': 'testset/testset\\img142.jpg', 'image_id': 'img142'},
#  {'image_path': 'testset/testset\\img143.jpg', 'image_id': 'img143'},
#  {'image_path': 'testset/testset\\img144.jpg', 'image_id': 'img144'},
#  {'image_path': 'testset/testset\\img145.jpg', 'image_id': 'img145'},
#  {'image_path': 'testset/testset\\img146.jpg', 'image_id': 'img146'},
#  {'image_path': 'testset/testset\\img147.jpg', 'image_id': 'img147'},
#  {'image_path': 'testset/testset\\img148.jpg', 'image_id': 'img148'},
#  {'image_path': 'testset/testset\\img149.jpg', 'image_id': 'img149'},
#  {'image_path': 'testset/testset\\img15.jpg', 'image_id': 'img15'},
#  {'image_path': 'testset/testset\\img150.jpg', 'image_id': 'img150'},
#  {'image_path': 'testset/testset\\img151.jpg', 'image_id': 'img151'},
#  {'image_path': 'testset/testset\\img152.jpg', 'image_id': 'img152'},
#  {'image_path': 'testset/testset\\img153.jpg', 'image_id': 'img153'},
#  {'image_path': 'testset/testset\\img154.jpg', 'image_id': 'img154'},
#  {'image_path': 'testset/testset\\img155.jpg', 'image_id': 'img155'},
#  {'image_path': 'testset/testset\\img156.jpg', 'image_id': 'img156'},
#  {'image_path': 'testset/testset\\img157.jpg', 'image_id': 'img157'},
#  {'image_path': 'testset/testset\\img158.jpg', 'image_id': 'img158'},
#  {'image_path': 'testset/testset\\img159.jpg', 'image_id': 'img159'},
#  {'image_path': 'testset/testset\\img16.jpg', 'image_id': 'img16'},
#  {'image_path': 'testset/testset\\img160.jpg', 'image_id': 'img160'},
#  {'image_path': 'testset/testset\\img161.jpg', 'image_id': 'img161'},
#  {'image_path': 'testset/testset\\img162.jpg', 'image_id': 'img162'},
#  {'image_path': 'testset/testset\\img163.jpg', 'image_id': 'img163'},
#  {'image_path': 'testset/testset\\img164.jpg', 'image_id': 'img164'},
#  {'image_path': 'testset/testset\\img165.jpg', 'image_id': 'img165'},
#  {'image_path': 'testset/testset\\img166.jpg', 'image_id': 'img166'},
#  {'image_path': 'testset/testset\\img167.jpg', 'image_id': 'img167'},
#  {'image_path': 'testset/testset\\img168.jpg', 'image_id': 'img168'},
#  {'image_path': 'testset/testset\\img169.jpg', 'image_id': 'img169'},
#  {'image_path': 'testset/testset\\img17.jpg', 'image_id': 'img17'},
#  {'image_path': 'testset/testset\\img170.jpg', 'image_id': 'img170'},
#  {'image_path': 'testset/testset\\img171.jpg', 'image_id': 'img171'},
#  {'image_path': 'testset/testset\\img172.jpg', 'image_id': 'img172'},
#  {'image_path': 'testset/testset\\img173.jpg', 'image_id': 'img173'},
#  {'image_path': 'testset/testset\\img174.jpg', 'image_id': 'img174'},
#  {'image_path': 'testset/testset\\img175.jpg', 'image_id': 'img175'},
#  {'image_path': 'testset/testset\\img176.jpg', 'image_id': 'img176'},
#  {'image_path': 'testset/testset\\img177.jpg', 'image_id': 'img177'},
#  {'image_path': 'testset/testset\\img178.jpg', 'image_id': 'img178'},
#  {'image_path': 'testset/testset\\img179.jpg', 'image_id': 'img179'},
#  {'image_path': 'testset/testset\\img18.jpg', 'image_id': 'img18'},
#  {'image_path': 'testset/testset\\img180.jpg', 'image_id': 'img180'},
#  {'image_path': 'testset/testset\\img181.jpg', 'image_id': 'img181'},
#  {'image_path': 'testset/testset\\img182.jpg', 'image_id': 'img182'},
#  {'image_path': 'testset/testset\\img183.jpg', 'image_id': 'img183'},
#  {'image_path': 'testset/testset\\img184.jpg', 'image_id': 'img184'},
#  {'image_path': 'testset/testset\\img185.jpg', 'image_id': 'img185'},
#  {'image_path': 'testset/testset\\img186.jpg', 'image_id': 'img186'},
#  {'image_path': 'testset/testset\\img187.jpg', 'image_id': 'img187'},
#  {'image_path': 'testset/testset\\img188.jpg', 'image_id': 'img188'},
#  {'image_path': 'testset/testset\\img189.jpg', 'image_id': 'img189'},
#  {'image_path': 'testset/testset\\img19.jpg', 'image_id': 'img19'},
#  {'image_path': 'testset/testset\\img190.jpg', 'image_id': 'img190'},
#  {'image_path': 'testset/testset\\img191.jpg', 'image_id': 'img191'},
#  {'image_path': 'testset/testset\\img192.jpg', 'image_id': 'img192'},
#  {'image_path': 'testset/testset\\img193.jpg', 'image_id': 'img193'},
#  {'image_path': 'testset/testset\\img194.jpg', 'image_id': 'img194'},
#  {'image_path': 'testset/testset\\img195.jpg', 'image_id': 'img195'},
#  {'image_path': 'testset/testset\\img196.jpg', 'image_id': 'img196'},
#  {'image_path': 'testset/testset\\img197.jpg', 'image_id': 'img197'},
#  {'image_path': 'testset/testset\\img198.jpg', 'image_id': 'img198'},
#  {'image_path': 'testset/testset\\img199.jpg', 'image_id': 'img199'},
#  {'image_path': 'testset/testset\\img2.jpg', 'image_id': 'img2'},
#  {'image_path': 'testset/testset\\img20.jpg', 'image_id': 'img20'},
#  {'image_path': 'testset/testset\\img200.jpg', 'image_id': 'img200'},
#  {'image_path': 'testset/testset\\img201.jpg', 'image_id': 'img201'},
#  {'image_path': 'testset/testset\\img202.jpg', 'image_id': 'img202'},
#  {'image_path': 'testset/testset\\img203.jpg', 'image_id': 'img203'},
#  {'image_path': 'testset/testset\\img204.jpg', 'image_id': 'img204'},
#  {'image_path': 'testset/testset\\img205.jpg', 'image_id': 'img205'},
#  {'image_path': 'testset/testset\\img206.jpg', 'image_id': 'img206'},
#  {'image_path': 'testset/testset\\img207.jpg', 'image_id': 'img207'},
#  {'image_path': 'testset/testset\\img208.jpg', 'image_id': 'img208'},
#  {'image_path': 'testset/testset\\img209.jpg', 'image_id': 'img209'},
#  {'image_path': 'testset/testset\\img21.jpg', 'image_id': 'img21'},
#  {'image_path': 'testset/testset\\img210.jpg', 'image_id': 'img210'},
#  {'image_path': 'testset/testset\\img211.jpg', 'image_id': 'img211'},
#  {'image_path': 'testset/testset\\img212.jpg', 'image_id': 'img212'},
#  {'image_path': 'testset/testset\\img213.jpg', 'image_id': 'img213'},
#  {'image_path': 'testset/testset\\img214.jpg', 'image_id': 'img214'},
#  {'image_path': 'testset/testset\\img215.jpg', 'image_id': 'img215'},
#  {'image_path': 'testset/testset\\img216.jpg', 'image_id': 'img216'},
#  {'image_path': 'testset/testset\\img217.jpg', 'image_id': 'img217'},
#  {'image_path': 'testset/testset\\img218.jpg', 'image_id': 'img218'},
#  {'image_path': 'testset/testset\\img219.jpg', 'image_id': 'img219'},
#  {'image_path': 'testset/testset\\img22.jpg', 'image_id': 'img22'},
#  {'image_path': 'testset/testset\\img220.jpg', 'image_id': 'img220'},
#  {'image_path': 'testset/testset\\img221.jpg', 'image_id': 'img221'},
#  {'image_path': 'testset/testset\\img222.jpg', 'image_id': 'img222'},
#  {'image_path': 'testset/testset\\img223.jpg', 'image_id': 'img223'},
#  {'image_path': 'testset/testset\\img224.jpg', 'image_id': 'img224'},
#  {'image_path': 'testset/testset\\img225.jpg', 'image_id': 'img225'},
#  {'image_path': 'testset/testset\\img226.jpg', 'image_id': 'img226'},
#  {'image_path': 'testset/testset\\img227.jpg', 'image_id': 'img227'},
#  {'image_path': 'testset/testset\\img228.jpg', 'image_id': 'img228'},
#  {'image_path': 'testset/testset\\img229.jpg', 'image_id': 'img229'},
#  {'image_path': 'testset/testset\\img23.jpg', 'image_id': 'img23'},
#  {'image_path': 'testset/testset\\img230.jpg', 'image_id': 'img230'},
#  {'image_path': 'testset/testset\\img231.jpg', 'image_id': 'img231'},
#  {'image_path': 'testset/testset\\img232.jpg', 'image_id': 'img232'},
#  {'image_path': 'testset/testset\\img233.jpg', 'image_id': 'img233'},
#  {'image_path': 'testset/testset\\img234.jpg', 'image_id': 'img234'},
#  {'image_path': 'testset/testset\\img235.jpg', 'image_id': 'img235'},
#  {'image_path': 'testset/testset\\img236.jpg', 'image_id': 'img236'},
#  {'image_path': 'testset/testset\\img237.jpg', 'image_id': 'img237'},
#  {'image_path': 'testset/testset\\img238.jpg', 'image_id': 'img238'},
#  {'image_path': 'testset/testset\\img239.jpg', 'image_id': 'img239'},
#  {'image_path': 'testset/testset\\img24.jpg', 'image_id': 'img24'},
#  {'image_path': 'testset/testset\\img240.jpg', 'image_id': 'img240'},
#  {'image_path': 'testset/testset\\img241.jpg', 'image_id': 'img241'},
#  {'image_path': 'testset/testset\\img242.jpg', 'image_id': 'img242'},
#  {'image_path': 'testset/testset\\img243.jpg', 'image_id': 'img243'},
#  {'image_path': 'testset/testset\\img244.jpg', 'image_id': 'img244'},
#  {'image_path': 'testset/testset\\img245.jpg', 'image_id': 'img245'},
#  {'image_path': 'testset/testset\\img246.jpg', 'image_id': 'img246'},
#  {'image_path': 'testset/testset\\img247.jpg', 'image_id': 'img247'},
#  {'image_path': 'testset/testset\\img248.jpg', 'image_id': 'img248'},
#  {'image_path': 'testset/testset\\img249.jpg', 'image_id': 'img249'},
#  {'image_path': 'testset/testset\\img25.jpg', 'image_id': 'img25'},
#  {'image_path': 'testset/testset\\img250.jpg', 'image_id': 'img250'},
#  {'image_path': 'testset/testset\\img251.jpg', 'image_id': 'img251'},
#  {'image_path': 'testset/testset\\img252.jpg', 'image_id': 'img252'},
#  {'image_path': 'testset/testset\\img253.jpg', 'image_id': 'img253'},
#  {'image_path': 'testset/testset\\img254.jpg', 'image_id': 'img254'},
#  {'image_path': 'testset/testset\\img255.jpg', 'image_id': 'img255'},
#  {'image_path': 'testset/testset\\img256.jpg', 'image_id': 'img256'},
#  {'image_path': 'testset/testset\\img257.jpg', 'image_id': 'img257'},
#  {'image_path': 'testset/testset\\img258.jpg', 'image_id': 'img258'},
#  {'image_path': 'testset/testset\\img259.jpg', 'image_id': 'img259'},
#  {'image_path': 'testset/testset\\img26.jpg', 'image_id': 'img26'},
#  {'image_path': 'testset/testset\\img260.jpg', 'image_id': 'img260'},
#  {'image_path': 'testset/testset\\img261.jpg', 'image_id': 'img261'},
#  {'image_path': 'testset/testset\\img262.jpg', 'image_id': 'img262'},
#  {'image_path': 'testset/testset\\img263.jpg', 'image_id': 'img263'},
#  {'image_path': 'testset/testset\\img264.jpg', 'image_id': 'img264'},
#  {'image_path': 'testset/testset\\img265.jpg', 'image_id': 'img265'},
#  {'image_path': 'testset/testset\\img266.jpg', 'image_id': 'img266'},
#  {'image_path': 'testset/testset\\img267.jpg', 'image_id': 'img267'},
#  {'image_path': 'testset/testset\\img268.jpg', 'image_id': 'img268'},
#  {'image_path': 'testset/testset\\img269.jpg', 'image_id': 'img269'},
#  {'image_path': 'testset/testset\\img27.jpg', 'image_id': 'img27'},
#  {'image_path': 'testset/testset\\img270.jpg', 'image_id': 'img270'},
#  {'image_path': 'testset/testset\\img271.jpg', 'image_id': 'img271'},
#  {'image_path': 'testset/testset\\img272.jpg', 'image_id': 'img272'},
#  {'image_path': 'testset/testset\\img273.jpg', 'image_id': 'img273'},
#  {'image_path': 'testset/testset\\img274.jpg', 'image_id': 'img274'},
#  {'image_path': 'testset/testset\\img275.jpg', 'image_id': 'img275'},
#  {'image_path': 'testset/testset\\img276.jpg', 'image_id': 'img276'},
#  {'image_path': 'testset/testset\\img277.jpg', 'image_id': 'img277'},
#  {'image_path': 'testset/testset\\img278.jpg', 'image_id': 'img278'},
#  {'image_path': 'testset/testset\\img279.jpg', 'image_id': 'img279'},
#  {'image_path': 'testset/testset\\img28.jpg', 'image_id': 'img28'},
#  {'image_path': 'testset/testset\\img280.jpg', 'image_id': 'img280'},
#  {'image_path': 'testset/testset\\img281.jpg', 'image_id': 'img281'},
#  {'image_path': 'testset/testset\\img282.jpg', 'image_id': 'img282'},
#  {'image_path': 'testset/testset\\img283.jpg', 'image_id': 'img283'},
#  {'image_path': 'testset/testset\\img284.jpg', 'image_id': 'img284'},
#  {'image_path': 'testset/testset\\img285.jpg', 'image_id': 'img285'},
#  {'image_path': 'testset/testset\\img286.jpg', 'image_id': 'img286'},
#  {'image_path': 'testset/testset\\img287.jpg', 'image_id': 'img287'},
#  {'image_path': 'testset/testset\\img288.jpg', 'image_id': 'img288'},
#  {'image_path': 'testset/testset\\img289.jpg', 'image_id': 'img289'},
#  {'image_path': 'testset/testset\\img29.jpg', 'image_id': 'img29'},
#  {'image_path': 'testset/testset\\img290.jpg', 'image_id': 'img290'},
#  {'image_path': 'testset/testset\\img291.jpg', 'image_id': 'img291'},
#  {'image_path': 'testset/testset\\img292.jpg', 'image_id': 'img292'},
#  {'image_path': 'testset/testset\\img293.jpg', 'image_id': 'img293'},
#  {'image_path': 'testset/testset\\img294.jpg', 'image_id': 'img294'},
#  {'image_path': 'testset/testset\\img295.jpg', 'image_id': 'img295'},
#  {'image_path': 'testset/testset\\img296.jpg', 'image_id': 'img296'},
#  {'image_path': 'testset/testset\\img297.jpg', 'image_id': 'img297'},
#  {'image_path': 'testset/testset\\img298.jpg', 'image_id': 'img298'},
#  {'image_path': 'testset/testset\\img299.jpg', 'image_id': 'img299'},
#  {'image_path': 'testset/testset\\img3.jpg', 'image_id': 'img3'},
#  {'image_path': 'testset/testset\\img30.jpg', 'image_id': 'img30'},
#  {'image_path': 'testset/testset\\img300.jpg', 'image_id': 'img300'},
#  {'image_path': 'testset/testset\\img301.jpg', 'image_id': 'img301'},
#  {'image_path': 'testset/testset\\img302.jpg', 'image_id': 'img302'},
#  {'image_path': 'testset/testset\\img303.jpg', 'image_id': 'img303'},
#  {'image_path': 'testset/testset\\img304.jpg', 'image_id': 'img304'},
#  {'image_path': 'testset/testset\\img305.jpg', 'image_id': 'img305'},
#  {'image_path': 'testset/testset\\img306.jpg', 'image_id': 'img306'},
#  {'image_path': 'testset/testset\\img307.jpg', 'image_id': 'img307'},
#  {'image_path': 'testset/testset\\img308.jpg', 'image_id': 'img308'},
#  {'image_path': 'testset/testset\\img309.jpg', 'image_id': 'img309'},
#  {'image_path': 'testset/testset\\img31.jpg', 'image_id': 'img31'},
#  {'image_path': 'testset/testset\\img310.jpg', 'image_id': 'img310'},
#  {'image_path': 'testset/testset\\img311.jpg', 'image_id': 'img311'},
#  {'image_path': 'testset/testset\\img312.jpg', 'image_id': 'img312'},
#  {'image_path': 'testset/testset\\img313.jpg', 'image_id': 'img313'},
#  {'image_path': 'testset/testset\\img314.jpg', 'image_id': 'img314'},
#  {'image_path': 'testset/testset\\img315.jpg', 'image_id': 'img315'},
#  {'image_path': 'testset/testset\\img316.jpg', 'image_id': 'img316'},
#  {'image_path': 'testset/testset\\img317.jpg', 'image_id': 'img317'},
#  {'image_path': 'testset/testset\\img318.jpg', 'image_id': 'img318'},
#  {'image_path': 'testset/testset\\img319.jpg', 'image_id': 'img319'},
#  {'image_path': 'testset/testset\\img32.jpg', 'image_id': 'img32'},
#  {'image_path': 'testset/testset\\img320.jpg', 'image_id': 'img320'},
#  {'image_path': 'testset/testset\\img321.jpg', 'image_id': 'img321'},
#  {'image_path': 'testset/testset\\img322.jpg', 'image_id': 'img322'},
#  {'image_path': 'testset/testset\\img323.jpg', 'image_id': 'img323'},
#  {'image_path': 'testset/testset\\img324.jpg', 'image_id': 'img324'},
#  {'image_path': 'testset/testset\\img325.jpg', 'image_id': 'img325'},
#  {'image_path': 'testset/testset\\img326.jpg', 'image_id': 'img326'},
#  {'image_path': 'testset/testset\\img327.jpg', 'image_id': 'img327'},
#  {'image_path': 'testset/testset\\img328.jpg', 'image_id': 'img328'},
#  {'image_path': 'testset/testset\\img329.jpg', 'image_id': 'img329'},
#  {'image_path': 'testset/testset\\img33.jpg', 'image_id': 'img33'},
#  {'image_path': 'testset/testset\\img330.jpg', 'image_id': 'img330'},
#  {'image_path': 'testset/testset\\img331.jpg', 'image_id': 'img331'},
#  {'image_path': 'testset/testset\\img332.jpg', 'image_id': 'img332'},
#  {'image_path': 'testset/testset\\img333.jpg', 'image_id': 'img333'},
#  {'image_path': 'testset/testset\\img334.jpg', 'image_id': 'img334'},
#  {'image_path': 'testset/testset\\img335.jpg', 'image_id': 'img335'},
#  {'image_path': 'testset/testset\\img336.jpg', 'image_id': 'img336'},
#  {'image_path': 'testset/testset\\img337.jpg', 'image_id': 'img337'},
#  {'image_path': 'testset/testset\\img338.jpg', 'image_id': 'img338'},
#  {'image_path': 'testset/testset\\img339.jpg', 'image_id': 'img339'},
#  {'image_path': 'testset/testset\\img34.jpg', 'image_id': 'img34'},
#  {'image_path': 'testset/testset\\img340.jpg', 'image_id': 'img340'},
#  {'image_path': 'testset/testset\\img341.jpg', 'image_id': 'img341'},
#  {'image_path': 'testset/testset\\img342.jpg', 'image_id': 'img342'},
#  {'image_path': 'testset/testset\\img343.jpg', 'image_id': 'img343'},
#  {'image_path': 'testset/testset\\img344.jpg', 'image_id': 'img344'},
#  {'image_path': 'testset/testset\\img345.jpg', 'image_id': 'img345'},
#  {'image_path': 'testset/testset\\img346.jpg', 'image_id': 'img346'},
#  {'image_path': 'testset/testset\\img347.jpg', 'image_id': 'img347'},
#  {'image_path': 'testset/testset\\img348.jpg', 'image_id': 'img348'},
#  {'image_path': 'testset/testset\\img349.jpg', 'image_id': 'img349'},
#  {'image_path': 'testset/testset\\img35.jpg', 'image_id': 'img35'},
#  {'image_path': 'testset/testset\\img350.jpg', 'image_id': 'img350'},
#  {'image_path': 'testset/testset\\img351.jpg', 'image_id': 'img351'},
#  {'image_path': 'testset/testset\\img352.jpg', 'image_id': 'img352'},
#  {'image_path': 'testset/testset\\img353.jpg', 'image_id': 'img353'},
#  {'image_path': 'testset/testset\\img354.jpg', 'image_id': 'img354'},
#  {'image_path': 'testset/testset\\img355.jpg', 'image_id': 'img355'},
#  {'image_path': 'testset/testset\\img356.jpg', 'image_id': 'img356'},
#  {'image_path': 'testset/testset\\img357.jpg', 'image_id': 'img357'},
#  {'image_path': 'testset/testset\\img358.jpg', 'image_id': 'img358'},
#  {'image_path': 'testset/testset\\img359.jpg', 'image_id': 'img359'},
#  {'image_path': 'testset/testset\\img36.jpg', 'image_id': 'img36'},
#  {'image_path': 'testset/testset\\img360.jpg', 'image_id': 'img360'},
#  {'image_path': 'testset/testset\\img361.jpg', 'image_id': 'img361'},
#  {'image_path': 'testset/testset\\img362.jpg', 'image_id': 'img362'},
#  {'image_path': 'testset/testset\\img363.jpg', 'image_id': 'img363'},
#  {'image_path': 'testset/testset\\img364.jpg', 'image_id': 'img364'},
#  {'image_path': 'testset/testset\\img365.jpg', 'image_id': 'img365'},
#  {'image_path': 'testset/testset\\img366.jpg', 'image_id': 'img366'},
#  {'image_path': 'testset/testset\\img367.jpg', 'image_id': 'img367'},
#  {'image_path': 'testset/testset\\img368.jpg', 'image_id': 'img368'},
#  {'image_path': 'testset/testset\\img369.jpg', 'image_id': 'img369'},
#  {'image_path': 'testset/testset\\img37.jpg', 'image_id': 'img37'},
#  {'image_path': 'testset/testset\\img370.jpg', 'image_id': 'img370'},
#  {'image_path': 'testset/testset\\img371.jpg', 'image_id': 'img371'},
#  {'image_path': 'testset/testset\\img372.jpg', 'image_id': 'img372'},
#  {'image_path': 'testset/testset\\img373.jpg', 'image_id': 'img373'},
#  {'image_path': 'testset/testset\\img374.jpg', 'image_id': 'img374'},
#  {'image_path': 'testset/testset\\img375.jpg', 'image_id': 'img375'},
#  {'image_path': 'testset/testset\\img376.jpg', 'image_id': 'img376'},
#  {'image_path': 'testset/testset\\img377.jpg', 'image_id': 'img377'},
#  {'image_path': 'testset/testset\\img378.jpg', 'image_id': 'img378'},
#  {'image_path': 'testset/testset\\img379.jpg', 'image_id': 'img379'},
#  {'image_path': 'testset/testset\\img38.jpg', 'image_id': 'img38'},
#  {'image_path': 'testset/testset\\img380.jpg', 'image_id': 'img380'},
#  {'image_path': 'testset/testset\\img381.jpg', 'image_id': 'img381'},
#  {'image_path': 'testset/testset\\img382.jpg', 'image_id': 'img382'},
#  {'image_path': 'testset/testset\\img383.jpg', 'image_id': 'img383'},
#  {'image_path': 'testset/testset\\img384.jpg', 'image_id': 'img384'},
#  {'image_path': 'testset/testset\\img385.jpg', 'image_id': 'img385'},
#  {'image_path': 'testset/testset\\img386.jpg', 'image_id': 'img386'},
#  {'image_path': 'testset/testset\\img387.jpg', 'image_id': 'img387'},
#  {'image_path': 'testset/testset\\img388.jpg', 'image_id': 'img388'},
#  {'image_path': 'testset/testset\\img389.jpg', 'image_id': 'img389'},
#  {'image_path': 'testset/testset\\img39.jpg', 'image_id': 'img39'},
#  {'image_path': 'testset/testset\\img390.jpg', 'image_id': 'img390'},
#  {'image_path': 'testset/testset\\img391.jpg', 'image_id': 'img391'},
#  {'image_path': 'testset/testset\\img392.jpg', 'image_id': 'img392'},
#  {'image_path': 'testset/testset\\img393.jpg', 'image_id': 'img393'},
#  {'image_path': 'testset/testset\\img394.jpg', 'image_id': 'img394'},
#  {'image_path': 'testset/testset\\img395.jpg', 'image_id': 'img395'},
#  {'image_path': 'testset/testset\\img396.jpg', 'image_id': 'img396'},
#  {'image_path': 'testset/testset\\img397.jpg', 'image_id': 'img397'},
#  {'image_path': 'testset/testset\\img398.jpg', 'image_id': 'img398'},
#  {'image_path': 'testset/testset\\img399.jpg', 'image_id': 'img399'},
#  {'image_path': 'testset/testset\\img4.jpg', 'image_id': 'img4'},
#  {'image_path': 'testset/testset\\img40.jpg', 'image_id': 'img40'},
#  {'image_path': 'testset/testset\\img400.jpg', 'image_id': 'img400'},
#  {'image_path': 'testset/testset\\img401.jpg', 'image_id': 'img401'},
#  {'image_path': 'testset/testset\\img402.jpg', 'image_id': 'img402'},
#  {'image_path': 'testset/testset\\img403.jpg', 'image_id': 'img403'},
#  {'image_path': 'testset/testset\\img404.jpg', 'image_id': 'img404'},
#  {'image_path': 'testset/testset\\img405.jpg', 'image_id': 'img405'},
#  {'image_path': 'testset/testset\\img406.jpg', 'image_id': 'img406'},
#  {'image_path': 'testset/testset\\img407.jpg', 'image_id': 'img407'},
#  {'image_path': 'testset/testset\\img408.jpg', 'image_id': 'img408'},
#  {'image_path': 'testset/testset\\img409.jpg', 'image_id': 'img409'},
#  {'image_path': 'testset/testset\\img41.jpg', 'image_id': 'img41'},
#  {'image_path': 'testset/testset\\img410.jpg', 'image_id': 'img410'},
#  {'image_path': 'testset/testset\\img411.jpg', 'image_id': 'img411'},
#  {'image_path': 'testset/testset\\img412.jpg', 'image_id': 'img412'},
#  {'image_path': 'testset/testset\\img413.jpg', 'image_id': 'img413'},
#  {'image_path': 'testset/testset\\img414.jpg', 'image_id': 'img414'},
#  {'image_path': 'testset/testset\\img415.jpg', 'image_id': 'img415'},
#  {'image_path': 'testset/testset\\img416.jpg', 'image_id': 'img416'},
#  {'image_path': 'testset/testset\\img417.jpg', 'image_id': 'img417'},
#  {'image_path': 'testset/testset\\img418.jpg', 'image_id': 'img418'},
#  {'image_path': 'testset/testset\\img419.jpg', 'image_id': 'img419'},
#  {'image_path': 'testset/testset\\img42.jpg', 'image_id': 'img42'},
#  {'image_path': 'testset/testset\\img420.jpg', 'image_id': 'img420'},
#  {'image_path': 'testset/testset\\img421.jpg', 'image_id': 'img421'},
#  {'image_path': 'testset/testset\\img422.jpg', 'image_id': 'img422'},
#  {'image_path': 'testset/testset\\img423.jpg', 'image_id': 'img423'},
#  {'image_path': 'testset/testset\\img424.jpg', 'image_id': 'img424'},
#  {'image_path': 'testset/testset\\img425.jpg', 'image_id': 'img425'},
#  {'image_path': 'testset/testset\\img426.jpg', 'image_id': 'img426'},
#  {'image_path': 'testset/testset\\img427.jpg', 'image_id': 'img427'},
#  {'image_path': 'testset/testset\\img428.jpg', 'image_id': 'img428'},
#  {'image_path': 'testset/testset\\img429.jpg', 'image_id': 'img429'},
#  {'image_path': 'testset/testset\\img43.jpg', 'image_id': 'img43'},
#  {'image_path': 'testset/testset\\img430.jpg', 'image_id': 'img430'},
#  {'image_path': 'testset/testset\\img431.jpg', 'image_id': 'img431'},
#  {'image_path': 'testset/testset\\img432.jpg', 'image_id': 'img432'},
#  {'image_path': 'testset/testset\\img433.jpg', 'image_id': 'img433'},
#  {'image_path': 'testset/testset\\img434.jpg', 'image_id': 'img434'},
#  {'image_path': 'testset/testset\\img435.jpg', 'image_id': 'img435'},
#  {'image_path': 'testset/testset\\img436.jpg', 'image_id': 'img436'},
#  {'image_path': 'testset/testset\\img437.jpg', 'image_id': 'img437'},
#  {'image_path': 'testset/testset\\img438.jpg', 'image_id': 'img438'},
#  {'image_path': 'testset/testset\\img439.jpg', 'image_id': 'img439'},
#  {'image_path': 'testset/testset\\img44.jpg', 'image_id': 'img44'},
#  {'image_path': 'testset/testset\\img440.jpg', 'image_id': 'img440'},
#  {'image_path': 'testset/testset\\img441.jpg', 'image_id': 'img441'},
#  {'image_path': 'testset/testset\\img442.jpg', 'image_id': 'img442'},
#  {'image_path': 'testset/testset\\img443.jpg', 'image_id': 'img443'},
#  {'image_path': 'testset/testset\\img444.jpg', 'image_id': 'img444'},
#  {'image_path': 'testset/testset\\img445.jpg', 'image_id': 'img445'},
#  {'image_path': 'testset/testset\\img446.jpg', 'image_id': 'img446'},
#  {'image_path': 'testset/testset\\img447.jpg', 'image_id': 'img447'},
#  {'image_path': 'testset/testset\\img448.jpg', 'image_id': 'img448'},
#  {'image_path': 'testset/testset\\img449.jpg', 'image_id': 'img449'},
#  {'image_path': 'testset/testset\\img45.jpg', 'image_id': 'img45'},
#  {'image_path': 'testset/testset\\img450.jpg', 'image_id': 'img450'},
#  {'image_path': 'testset/testset\\img451.jpg', 'image_id': 'img451'},
#  {'image_path': 'testset/testset\\img452.jpg', 'image_id': 'img452'},
#  {'image_path': 'testset/testset\\img453.jpg', 'image_id': 'img453'},
#  {'image_path': 'testset/testset\\img454.jpg', 'image_id': 'img454'},
#  {'image_path': 'testset/testset\\img455.jpg', 'image_id': 'img455'},
#  {'image_path': 'testset/testset\\img456.jpg', 'image_id': 'img456'},
#  {'image_path': 'testset/testset\\img457.jpg', 'image_id': 'img457'},
#  {'image_path': 'testset/testset\\img458.jpg', 'image_id': 'img458'},
#  {'image_path': 'testset/testset\\img459.jpg', 'image_id': 'img459'},
#  {'image_path': 'testset/testset\\img46.jpg', 'image_id': 'img46'},
#  {'image_path': 'testset/testset\\img460.jpg', 'image_id': 'img460'},
#  {'image_path': 'testset/testset\\img461.jpg', 'image_id': 'img461'},
#  {'image_path': 'testset/testset\\img462.jpg', 'image_id': 'img462'},
#  {'image_path': 'testset/testset\\img463.jpg', 'image_id': 'img463'},
#  {'image_path': 'testset/testset\\img464.jpg', 'image_id': 'img464'},
#  {'image_path': 'testset/testset\\img465.jpg', 'image_id': 'img465'},
#  {'image_path': 'testset/testset\\img466.jpg', 'image_id': 'img466'},
#  {'image_path': 'testset/testset\\img467.jpg', 'image_id': 'img467'},
#  {'image_path': 'testset/testset\\img468.jpg', 'image_id': 'img468'},
#  {'image_path': 'testset/testset\\img469.jpg', 'image_id': 'img469'},
#  {'image_path': 'testset/testset\\img47.jpg', 'image_id': 'img47'},
#  {'image_path': 'testset/testset\\img470.jpg', 'image_id': 'img470'},
#  {'image_path': 'testset/testset\\img471.jpg', 'image_id': 'img471'},
#  {'image_path': 'testset/testset\\img472.jpg', 'image_id': 'img472'},
#  {'image_path': 'testset/testset\\img473.jpg', 'image_id': 'img473'},
#  {'image_path': 'testset/testset\\img474.jpg', 'image_id': 'img474'},
#  {'image_path': 'testset/testset\\img475.jpg', 'image_id': 'img475'},
#  {'image_path': 'testset/testset\\img476.jpg', 'image_id': 'img476'},
#  {'image_path': 'testset/testset\\img477.jpg', 'image_id': 'img477'},
#  {'image_path': 'testset/testset\\img478.jpg', 'image_id': 'img478'},
#  {'image_path': 'testset/testset\\img479.jpg', 'image_id': 'img479'},
#  {'image_path': 'testset/testset\\img48.jpg', 'image_id': 'img48'},
#  {'image_path': 'testset/testset\\img480.jpg', 'image_id': 'img480'},
#  {'image_path': 'testset/testset\\img481.jpg', 'image_id': 'img481'},
#  {'image_path': 'testset/testset\\img482.jpg', 'image_id': 'img482'},
#  {'image_path': 'testset/testset\\img483.jpg', 'image_id': 'img483'},
#  {'image_path': 'testset/testset\\img484.jpg', 'image_id': 'img484'},
#  {'image_path': 'testset/testset\\img485.jpg', 'image_id': 'img485'},
#  {'image_path': 'testset/testset\\img486.jpg', 'image_id': 'img486'},
#  {'image_path': 'testset/testset\\img487.jpg', 'image_id': 'img487'},
#  {'image_path': 'testset/testset\\img488.jpg', 'image_id': 'img488'},
#  {'image_path': 'testset/testset\\img489.jpg', 'image_id': 'img489'},
#  {'image_path': 'testset/testset\\img49.jpg', 'image_id': 'img49'},
#  {'image_path': 'testset/testset\\img490.jpg', 'image_id': 'img490'},
#  {'image_path': 'testset/testset\\img491.jpg', 'image_id': 'img491'},
#  {'image_path': 'testset/testset\\img492.jpg', 'image_id': 'img492'},
#  {'image_path': 'testset/testset\\img493.jpg', 'image_id': 'img493'},
#  {'image_path': 'testset/testset\\img494.jpg', 'image_id': 'img494'},
#  {'image_path': 'testset/testset\\img495.jpg', 'image_id': 'img495'},
#  {'image_path': 'testset/testset\\img496.jpg', 'image_id': 'img496'},
#  {'image_path': 'testset/testset\\img497.jpg', 'image_id': 'img497'},
#  {'image_path': 'testset/testset\\img498.jpg', 'image_id': 'img498'},
#  {'image_path': 'testset/testset\\img499.jpg', 'image_id': 'img499'},
#  {'image_path': 'testset/testset\\img5.jpg', 'image_id': 'img5'},
#  {'image_path': 'testset/testset\\img50.jpg', 'image_id': 'img50'},
#  {'image_path': 'testset/testset\\img500.jpg', 'image_id': 'img500'},
#  {'image_path': 'testset/testset\\img501.jpg', 'image_id': 'img501'},
#  {'image_path': 'testset/testset\\img502.jpg', 'image_id': 'img502'},
#  {'image_path': 'testset/testset\\img503.jpg', 'image_id': 'img503'},
#  {'image_path': 'testset/testset\\img504.jpg', 'image_id': 'img504'},
#  {'image_path': 'testset/testset\\img505.jpg', 'image_id': 'img505'},
#  {'image_path': 'testset/testset\\img506.jpg', 'image_id': 'img506'},
#  {'image_path': 'testset/testset\\img507.jpg', 'image_id': 'img507'},
#  {'image_path': 'testset/testset\\img508.jpg', 'image_id': 'img508'},
#  {'image_path': 'testset/testset\\img509.jpg', 'image_id': 'img509'},
#  {'image_path': 'testset/testset\\img51.jpg', 'image_id': 'img51'},
#  {'image_path': 'testset/testset\\img510.jpg', 'image_id': 'img510'},
#  {'image_path': 'testset/testset\\img511.jpg', 'image_id': 'img511'},
#  {'image_path': 'testset/testset\\img512.jpg', 'image_id': 'img512'},
#  {'image_path': 'testset/testset\\img513.jpg', 'image_id': 'img513'},
#  {'image_path': 'testset/testset\\img514.jpg', 'image_id': 'img514'},
#  {'image_path': 'testset/testset\\img515.jpg', 'image_id': 'img515'},
#  {'image_path': 'testset/testset\\img516.jpg', 'image_id': 'img516'},
#  {'image_path': 'testset/testset\\img517.jpg', 'image_id': 'img517'},
#  {'image_path': 'testset/testset\\img518.jpg', 'image_id': 'img518'},
#  {'image_path': 'testset/testset\\img519.jpg', 'image_id': 'img519'},
#  {'image_path': 'testset/testset\\img52.jpg', 'image_id': 'img52'},
#  {'image_path': 'testset/testset\\img520.jpg', 'image_id': 'img520'},
#  {'image_path': 'testset/testset\\img521.jpg', 'image_id': 'img521'},
#  {'image_path': 'testset/testset\\img522.jpg', 'image_id': 'img522'},
#  {'image_path': 'testset/testset\\img523.jpg', 'image_id': 'img523'},
#  {'image_path': 'testset/testset\\img524.jpg', 'image_id': 'img524'},
#  {'image_path': 'testset/testset\\img525.jpg', 'image_id': 'img525'},
#  {'image_path': 'testset/testset\\img526.jpg', 'image_id': 'img526'},
#  {'image_path': 'testset/testset\\img527.jpg', 'image_id': 'img527'},
#  {'image_path': 'testset/testset\\img528.jpg', 'image_id': 'img528'},
#  {'image_path': 'testset/testset\\img529.jpg', 'image_id': 'img529'},
#  {'image_path': 'testset/testset\\img53.jpg', 'image_id': 'img53'},
#  {'image_path': 'testset/testset\\img530.jpg', 'image_id': 'img530'},
#  {'image_path': 'testset/testset\\img531.jpg', 'image_id': 'img531'},
#  {'image_path': 'testset/testset\\img532.jpg', 'image_id': 'img532'},
#  {'image_path': 'testset/testset\\img533.jpg', 'image_id': 'img533'},
#  {'image_path': 'testset/testset\\img534.jpg', 'image_id': 'img534'},
#  {'image_path': 'testset/testset\\img535.jpg', 'image_id': 'img535'},
#  {'image_path': 'testset/testset\\img536.jpg', 'image_id': 'img536'},
#  {'image_path': 'testset/testset\\img537.jpg', 'image_id': 'img537'},
#  {'image_path': 'testset/testset\\img538.jpg', 'image_id': 'img538'},
#  {'image_path': 'testset/testset\\img539.jpg', 'image_id': 'img539'},
#  {'image_path': 'testset/testset\\img54.jpg', 'image_id': 'img54'},
#  {'image_path': 'testset/testset\\img540.jpg', 'image_id': 'img540'},
#  {'image_path': 'testset/testset\\img541.jpg', 'image_id': 'img541'},
#  {'image_path': 'testset/testset\\img542.jpg', 'image_id': 'img542'},
#  {'image_path': 'testset/testset\\img543.jpg', 'image_id': 'img543'},
#  {'image_path': 'testset/testset\\img544.jpg', 'image_id': 'img544'},
#  {'image_path': 'testset/testset\\img545.jpg', 'image_id': 'img545'},
#  {'image_path': 'testset/testset\\img546.jpg', 'image_id': 'img546'},
#  {'image_path': 'testset/testset\\img547.jpg', 'image_id': 'img547'},
#  {'image_path': 'testset/testset\\img548.jpg', 'image_id': 'img548'},
#  {'image_path': 'testset/testset\\img549.jpg', 'image_id': 'img549'},
#  {'image_path': 'testset/testset\\img55.jpg', 'image_id': 'img55'},
#  {'image_path': 'testset/testset\\img550.jpg', 'image_id': 'img550'},
#  {'image_path': 'testset/testset\\img551.jpg', 'image_id': 'img551'},
#  {'image_path': 'testset/testset\\img552.jpg', 'image_id': 'img552'},
#  {'image_path': 'testset/testset\\img553.jpg', 'image_id': 'img553'},
#  {'image_path': 'testset/testset\\img554.jpg', 'image_id': 'img554'},
#  {'image_path': 'testset/testset\\img555.jpg', 'image_id': 'img555'},
#  {'image_path': 'testset/testset\\img556.jpg', 'image_id': 'img556'},
#  {'image_path': 'testset/testset\\img557.jpg', 'image_id': 'img557'},
#  {'image_path': 'testset/testset\\img558.jpg', 'image_id': 'img558'},
#  {'image_path': 'testset/testset\\img559.jpg', 'image_id': 'img559'},
#  {'image_path': 'testset/testset\\img56.jpg', 'image_id': 'img56'},
#  {'image_path': 'testset/testset\\img560.jpg', 'image_id': 'img560'},
#  {'image_path': 'testset/testset\\img561.jpg', 'image_id': 'img561'},
#  {'image_path': 'testset/testset\\img562.jpg', 'image_id': 'img562'},
#  {'image_path': 'testset/testset\\img563.jpg', 'image_id': 'img563'},
#  {'image_path': 'testset/testset\\img564.jpg', 'image_id': 'img564'},
#  {'image_path': 'testset/testset\\img565.jpg', 'image_id': 'img565'},
#  {'image_path': 'testset/testset\\img566.jpg', 'image_id': 'img566'},
#  {'image_path': 'testset/testset\\img567.jpg', 'image_id': 'img567'},
#  {'image_path': 'testset/testset\\img568.jpg', 'image_id': 'img568'},
#  {'image_path': 'testset/testset\\img569.jpg', 'image_id': 'img569'},
#  {'image_path': 'testset/testset\\img57.jpg', 'image_id': 'img57'},
#  {'image_path': 'testset/testset\\img570.jpg', 'image_id': 'img570'},
#  {'image_path': 'testset/testset\\img571.jpg', 'image_id': 'img571'},
#  {'image_path': 'testset/testset\\img572.jpg', 'image_id': 'img572'},
#  {'image_path': 'testset/testset\\img573.jpg', 'image_id': 'img573'},
#  {'image_path': 'testset/testset\\img574.jpg', 'image_id': 'img574'},
#  {'image_path': 'testset/testset\\img575.jpg', 'image_id': 'img575'},
#  {'image_path': 'testset/testset\\img576.jpg', 'image_id': 'img576'},
#  {'image_path': 'testset/testset\\img577.jpg', 'image_id': 'img577'},
#  {'image_path': 'testset/testset\\img578.jpg', 'image_id': 'img578'},
#  {'image_path': 'testset/testset\\img579.jpg', 'image_id': 'img579'},
#  {'image_path': 'testset/testset\\img58.jpg', 'image_id': 'img58'},
#  {'image_path': 'testset/testset\\img580.jpg', 'image_id': 'img580'},
#  {'image_path': 'testset/testset\\img581.jpg', 'image_id': 'img581'},
#  {'image_path': 'testset/testset\\img582.jpg', 'image_id': 'img582'},
#  {'image_path': 'testset/testset\\img583.jpg', 'image_id': 'img583'},
#  {'image_path': 'testset/testset\\img584.jpg', 'image_id': 'img584'},
#  {'image_path': 'testset/testset\\img585.jpg', 'image_id': 'img585'},
#  {'image_path': 'testset/testset\\img586.jpg', 'image_id': 'img586'},
#  {'image_path': 'testset/testset\\img587.jpg', 'image_id': 'img587'},
#  {'image_path': 'testset/testset\\img588.jpg', 'image_id': 'img588'},
#  {'image_path': 'testset/testset\\img589.jpg', 'image_id': 'img589'},
#  {'image_path': 'testset/testset\\img59.jpg', 'image_id': 'img59'},
#  {'image_path': 'testset/testset\\img590.jpg', 'image_id': 'img590'},
#  {'image_path': 'testset/testset\\img591.jpg', 'image_id': 'img591'},
#  {'image_path': 'testset/testset\\img592.jpg', 'image_id': 'img592'},
#  {'image_path': 'testset/testset\\img593.jpg', 'image_id': 'img593'},
#  {'image_path': 'testset/testset\\img594.jpg', 'image_id': 'img594'},
#  {'image_path': 'testset/testset\\img595.jpg', 'image_id': 'img595'},
#  {'image_path': 'testset/testset\\img596.jpg', 'image_id': 'img596'},
#  {'image_path': 'testset/testset\\img597.jpg', 'image_id': 'img597'},
#  {'image_path': 'testset/testset\\img598.jpg', 'image_id': 'img598'},
#  {'image_path': 'testset/testset\\img599.jpg', 'image_id': 'img599'},
#  {'image_path': 'testset/testset\\img6.jpg', 'image_id': 'img6'},
#  {'image_path': 'testset/testset\\img60.jpg', 'image_id': 'img60'},
#  {'image_path': 'testset/testset\\img600.jpg', 'image_id': 'img600'},
#  {'image_path': 'testset/testset\\img601.jpg', 'image_id': 'img601'},
#  {'image_path': 'testset/testset\\img602.jpg', 'image_id': 'img602'},
#  {'image_path': 'testset/testset\\img603.jpg', 'image_id': 'img603'},
#  {'image_path': 'testset/testset\\img604.jpg', 'image_id': 'img604'},
#  {'image_path': 'testset/testset\\img605.jpg', 'image_id': 'img605'},
#  {'image_path': 'testset/testset\\img606.jpg', 'image_id': 'img606'},
#  {'image_path': 'testset/testset\\img607.jpg', 'image_id': 'img607'},
#  {'image_path': 'testset/testset\\img608.jpg', 'image_id': 'img608'},
#  {'image_path': 'testset/testset\\img609.jpg', 'image_id': 'img609'},
#  {'image_path': 'testset/testset\\img61.jpg', 'image_id': 'img61'},
#  {'image_path': 'testset/testset\\img610.jpg', 'image_id': 'img610'},
#  {'image_path': 'testset/testset\\img611.jpg', 'image_id': 'img611'},
#  {'image_path': 'testset/testset\\img612.jpg', 'image_id': 'img612'},
#  {'image_path': 'testset/testset\\img613.jpg', 'image_id': 'img613'},
#  {'image_path': 'testset/testset\\img614.jpg', 'image_id': 'img614'},
#  {'image_path': 'testset/testset\\img615.jpg', 'image_id': 'img615'},
#  {'image_path': 'testset/testset\\img616.jpg', 'image_id': 'img616'},
#  {'image_path': 'testset/testset\\img617.jpg', 'image_id': 'img617'},
#  {'image_path': 'testset/testset\\img618.jpg', 'image_id': 'img618'},
#  {'image_path': 'testset/testset\\img619.jpg', 'image_id': 'img619'},
#  {'image_path': 'testset/testset\\img62.jpg', 'image_id': 'img62'},
#  {'image_path': 'testset/testset\\img620.jpg', 'image_id': 'img620'},
#  {'image_path': 'testset/testset\\img621.jpg', 'image_id': 'img621'},
#  {'image_path': 'testset/testset\\img622.jpg', 'image_id': 'img622'},
#  {'image_path': 'testset/testset\\img623.jpg', 'image_id': 'img623'},
#  {'image_path': 'testset/testset\\img624.jpg', 'image_id': 'img624'},
#  {'image_path': 'testset/testset\\img625.jpg', 'image_id': 'img625'},
#  {'image_path': 'testset/testset\\img626.jpg', 'image_id': 'img626'},
#  {'image_path': 'testset/testset\\img627.jpg', 'image_id': 'img627'},
#  {'image_path': 'testset/testset\\img628.jpg', 'image_id': 'img628'},
#  {'image_path': 'testset/testset\\img629.jpg', 'image_id': 'img629'},
#  {'image_path': 'testset/testset\\img63.jpg', 'image_id': 'img63'},
#  {'image_path': 'testset/testset\\img630.jpg', 'image_id': 'img630'},
#  {'image_path': 'testset/testset\\img631.jpg', 'image_id': 'img631'},
#  {'image_path': 'testset/testset\\img632.jpg', 'image_id': 'img632'},
#  {'image_path': 'testset/testset\\img633.jpg', 'image_id': 'img633'},
#  {'image_path': 'testset/testset\\img634.jpg', 'image_id': 'img634'},
#  {'image_path': 'testset/testset\\img635.jpg', 'image_id': 'img635'},
#  {'image_path': 'testset/testset\\img636.jpg', 'image_id': 'img636'},
#  {'image_path': 'testset/testset\\img637.jpg', 'image_id': 'img637'},
#  {'image_path': 'testset/testset\\img638.jpg', 'image_id': 'img638'},
#  {'image_path': 'testset/testset\\img639.jpg', 'image_id': 'img639'},
#  {'image_path': 'testset/testset\\img64.jpg', 'image_id': 'img64'},
#  {'image_path': 'testset/testset\\img640.jpg', 'image_id': 'img640'},
#  {'image_path': 'testset/testset\\img641.jpg', 'image_id': 'img641'},
#  {'image_path': 'testset/testset\\img642.jpg', 'image_id': 'img642'},
#  {'image_path': 'testset/testset\\img643.jpg', 'image_id': 'img643'},
#  {'image_path': 'testset/testset\\img644.jpg', 'image_id': 'img644'},
#  {'image_path': 'testset/testset\\img645.jpg', 'image_id': 'img645'},
#  {'image_path': 'testset/testset\\img646.jpg', 'image_id': 'img646'},
#  {'image_path': 'testset/testset\\img647.jpg', 'image_id': 'img647'},
#  {'image_path': 'testset/testset\\img648.jpg', 'image_id': 'img648'},
#  {'image_path': 'testset/testset\\img649.jpg', 'image_id': 'img649'},
#  {'image_path': 'testset/testset\\img65.jpg', 'image_id': 'img65'},
#  {'image_path': 'testset/testset\\img650.jpg', 'image_id': 'img650'},
#  {'image_path': 'testset/testset\\img651.jpg', 'image_id': 'img651'},
#  {'image_path': 'testset/testset\\img652.jpg', 'image_id': 'img652'},
#  {'image_path': 'testset/testset\\img653.jpg', 'image_id': 'img653'},
#  {'image_path': 'testset/testset\\img654.jpg', 'image_id': 'img654'},
#  {'image_path': 'testset/testset\\img655.jpg', 'image_id': 'img655'},
#  {'image_path': 'testset/testset\\img656.jpg', 'image_id': 'img656'},
#  {'image_path': 'testset/testset\\img657.jpg', 'image_id': 'img657'},
#  {'image_path': 'testset/testset\\img658.jpg', 'image_id': 'img658'},
#  {'image_path': 'testset/testset\\img659.jpg', 'image_id': 'img659'},
#  {'image_path': 'testset/testset\\img66.jpg', 'image_id': 'img66'},
#  {'image_path': 'testset/testset\\img660.jpg', 'image_id': 'img660'},
#  {'image_path': 'testset/testset\\img661.jpg', 'image_id': 'img661'},
#  {'image_path': 'testset/testset\\img662.jpg', 'image_id': 'img662'},
#  {'image_path': 'testset/testset\\img663.jpg', 'image_id': 'img663'},
#  {'image_path': 'testset/testset\\img664.jpg', 'image_id': 'img664'},
#  {'image_path': 'testset/testset\\img665.jpg', 'image_id': 'img665'},
#  {'image_path': 'testset/testset\\img666.jpg', 'image_id': 'img666'},
#  {'image_path': 'testset/testset\\img667.jpg', 'image_id': 'img667'},
#  {'image_path': 'testset/testset\\img668.jpg', 'image_id': 'img668'},
#  {'image_path': 'testset/testset\\img669.jpg', 'image_id': 'img669'},
#  {'image_path': 'testset/testset\\img67.jpg', 'image_id': 'img67'},
#  {'image_path': 'testset/testset\\img670.jpg', 'image_id': 'img670'},
#  {'image_path': 'testset/testset\\img671.jpg', 'image_id': 'img671'},
#  {'image_path': 'testset/testset\\img672.jpg', 'image_id': 'img672'},
#  {'image_path': 'testset/testset\\img673.jpg', 'image_id': 'img673'},
#  {'image_path': 'testset/testset\\img674.jpg', 'image_id': 'img674'},
#  {'image_path': 'testset/testset\\img675.jpg', 'image_id': 'img675'},
#  {'image_path': 'testset/testset\\img676.jpg', 'image_id': 'img676'},
#  {'image_path': 'testset/testset\\img677.jpg', 'image_id': 'img677'},
#  {'image_path': 'testset/testset\\img678.jpg', 'image_id': 'img678'},
#  {'image_path': 'testset/testset\\img679.jpg', 'image_id': 'img679'},
#  {'image_path': 'testset/testset\\img68.jpg', 'image_id': 'img68'},
#  {'image_path': 'testset/testset\\img680.jpg', 'image_id': 'img680'},
#  {'image_path': 'testset/testset\\img681.jpg', 'image_id': 'img681'},
#  {'image_path': 'testset/testset\\img682.jpg', 'image_id': 'img682'},
#  {'image_path': 'testset/testset\\img683.jpg', 'image_id': 'img683'},
#  {'image_path': 'testset/testset\\img684.jpg', 'image_id': 'img684'},
#  {'image_path': 'testset/testset\\img685.jpg', 'image_id': 'img685'},
#  {'image_path': 'testset/testset\\img686.jpg', 'image_id': 'img686'},
#  {'image_path': 'testset/testset\\img687.jpg', 'image_id': 'img687'},
#  {'image_path': 'testset/testset\\img688.jpg', 'image_id': 'img688'},
#  {'image_path': 'testset/testset\\img689.jpg', 'image_id': 'img689'},
#  {'image_path': 'testset/testset\\img69.jpg', 'image_id': 'img69'},
#  {'image_path': 'testset/testset\\img690.jpg', 'image_id': 'img690'},
#  {'image_path': 'testset/testset\\img691.jpg', 'image_id': 'img691'},
#  {'image_path': 'testset/testset\\img692.jpg', 'image_id': 'img692'},
#  {'image_path': 'testset/testset\\img693.jpg', 'image_id': 'img693'},
#  {'image_path': 'testset/testset\\img694.jpg', 'image_id': 'img694'},
#  {'image_path': 'testset/testset\\img695.jpg', 'image_id': 'img695'},
#  {'image_path': 'testset/testset\\img696.jpg', 'image_id': 'img696'},
#  {'image_path': 'testset/testset\\img697.jpg', 'image_id': 'img697'},
#  {'image_path': 'testset/testset\\img698.jpg', 'image_id': 'img698'},
#  {'image_path': 'testset/testset\\img699.jpg', 'image_id': 'img699'},
#  {'image_path': 'testset/testset\\img7.jpg', 'image_id': 'img7'},
#  {'image_path': 'testset/testset\\img70.jpg', 'image_id': 'img70'},
#  {'image_path': 'testset/testset\\img700.jpg', 'image_id': 'img700'},
#  {'image_path': 'testset/testset\\img701.jpg', 'image_id': 'img701'},
#  {'image_path': 'testset/testset\\img702.jpg', 'image_id': 'img702'},
#  {'image_path': 'testset/testset\\img703.jpg', 'image_id': 'img703'},
#  {'image_path': 'testset/testset\\img704.jpg', 'image_id': 'img704'},
#  {'image_path': 'testset/testset\\img705.jpg', 'image_id': 'img705'},
#  {'image_path': 'testset/testset\\img706.jpg', 'image_id': 'img706'},
#  {'image_path': 'testset/testset\\img707.jpg', 'image_id': 'img707'},
#  {'image_path': 'testset/testset\\img708.jpg', 'image_id': 'img708'},
#  {'image_path': 'testset/testset\\img709.jpg', 'image_id': 'img709'},
#  {'image_path': 'testset/testset\\img71.jpg', 'image_id': 'img71'},
#  {'image_path': 'testset/testset\\img710.jpg', 'image_id': 'img710'},
#  {'image_path': 'testset/testset\\img711.jpg', 'image_id': 'img711'},
#  {'image_path': 'testset/testset\\img712.jpg', 'image_id': 'img712'},
#  {'image_path': 'testset/testset\\img713.jpg', 'image_id': 'img713'},
#  {'image_path': 'testset/testset\\img714.jpg', 'image_id': 'img714'},
#  {'image_path': 'testset/testset\\img715.jpg', 'image_id': 'img715'},
#  {'image_path': 'testset/testset\\img716.jpg', 'image_id': 'img716'},
# ...
#  {'image_path': 'testset/testset\\img785.jpg', 'image_id': 'img785'},
#  {'image_path': 'testset/testset\\img786.jpg', 'image_id': 'img786'},
#  {'image_path': 'testset/testset\\img787.jpg', 'image_id': 'img787'},
#  {'image_path': 'testset/testset\\img788.jpg', 'image_id': 'img788'},
#  {'image_path': 'testset/testset\\img789.jpg', 'image_id': 'img789'},
#  {'image_path': 'testset/testset\\img79.jpg', 'image_id': 'img79'},
#  {'image_path': 'testset/testset\\img790.jpg', 'image_id': 'img790'},
#  {'image_path': 'testset/testset\\img791.jpg', 'image_id': 'img791'},
#  {'image_path': 'testset/testset\\img792.jpg', 'image_id': 'img792'},
#  {'image_path': 'testset/testset\\img793.jpg', 'image_id': 'img793'},
#  {'image_path': 'testset/testset\\img794.jpg', 'image_id': 'img794'},
#  {'image_path': 'testset/testset\\img795.jpg', 'image_id': 'img795'},
#  {'image_path': 'testset/testset\\img796.jpg', 'image_id': 'img796'},
#  {'image_path': 'testset/testset\\img797.jpg', 'image_id': 'img797'},
#  {'image_path': 'testset/testset\\img798.jpg', 'image_id': 'img798'},
#  {'image_path': 'testset/testset\\img799.jpg', 'image_id': 'img799'},
#  {'image_path': 'testset/testset\\img8.jpg', 'image_id': 'img8'},
#  {'image_path': 'testset/testset\\img80.jpg', 'image_id': 'img80'},
#  {'image_path': 'testset/testset\\img800.jpg', 'image_id': 'img800'},
#  {'image_path': 'testset/testset\\img801.jpg', 'image_id': 'img801'},
#  {'image_path': 'testset/testset\\img802.jpg', 'image_id': 'img802'},
#  {'image_path': 'testset/testset\\img803.jpg', 'image_id': 'img803'},
#  {'image_path': 'testset/testset\\img804.jpg', 'image_id': 'img804'},
#  {'image_path': 'testset/testset\\img805.jpg', 'image_id': 'img805'},
#  {'image_path': 'testset/testset\\img806.jpg', 'image_id': 'img806'},
#  {'image_path': 'testset/testset\\img807.jpg', 'image_id': 'img807'},
#  {'image_path': 'testset/testset\\img808.jpg', 'image_id': 'img808'},
#  {'image_path': 'testset/testset\\img809.jpg', 'image_id': 'img809'},
#  {'image_path': 'testset/testset\\img81.jpg', 'image_id': 'img81'},
#  {'image_path': 'testset/testset\\img810.jpg', 'image_id': 'img810'},
#  {'image_path': 'testset/testset\\img811.jpg', 'image_id': 'img811'},
#  {'image_path': 'testset/testset\\img812.jpg', 'image_id': 'img812'},
#  {'image_path': 'testset/testset\\img813.jpg', 'image_id': 'img813'},
#  {'image_path': 'testset/testset\\img814.jpg', 'image_id': 'img814'},
#  {'image_path': 'testset/testset\\img815.jpg', 'image_id': 'img815'},
#  {'image_path': 'testset/testset\\img816.jpg', 'image_id': 'img816'},
#  {'image_path': 'testset/testset\\img817.jpg', 'image_id': 'img817'},
#  {'image_path': 'testset/testset\\img818.jpg', 'image_id': 'img818'},
#  {'image_path': 'testset/testset\\img819.jpg', 'image_id': 'img819'},
#  {'image_path': 'testset/testset\\img82.jpg', 'image_id': 'img82'},
#  {'image_path': 'testset/testset\\img820.jpg', 'image_id': 'img820'},
#  {'image_path': 'testset/testset\\img821.jpg', 'image_id': 'img821'},
#  {'image_path': 'testset/testset\\img822.jpg', 'image_id': 'img822'},
#  {'image_path': 'testset/testset\\img823.jpg', 'image_id': 'img823'},
#  {'image_path': 'testset/testset\\img824.jpg', 'image_id': 'img824'},
#  {'image_path': 'testset/testset\\img825.jpg', 'image_id': 'img825'},
#  {'image_path': 'testset/testset\\img826.jpg', 'image_id': 'img826'},
#  {'image_path': 'testset/testset\\img827.jpg', 'image_id': 'img827'},
#  {'image_path': 'testset/testset\\img828.jpg', 'image_id': 'img828'},
#  {'image_path': 'testset/testset\\img829.jpg', 'image_id': 'img829'},
#  {'image_path': 'testset/testset\\img83.jpg', 'image_id': 'img83'},
#  {'image_path': 'testset/testset\\img830.jpg', 'image_id': 'img830'},
#  {'image_path': 'testset/testset\\img831.jpg', 'image_id': 'img831'},
#  {'image_path': 'testset/testset\\img832.jpg', 'image_id': 'img832'},
#  {'image_path': 'testset/testset\\img833.jpg', 'image_id': 'img833'},
#  {'image_path': 'testset/testset\\img834.jpg', 'image_id': 'img834'},
#  {'image_path': 'testset/testset\\img835.jpg', 'image_id': 'img835'},
#  {'image_path': 'testset/testset\\img836.jpg', 'image_id': 'img836'},
#  {'image_path': 'testset/testset\\img837.jpg', 'image_id': 'img837'},
#  {'image_path': 'testset/testset\\img838.jpg', 'image_id': 'img838'},
#  {'image_path': 'testset/testset\\img839.jpg', 'image_id': 'img839'},
#  {'image_path': 'testset/testset\\img84.jpg', 'image_id': 'img84'},
#  {'image_path': 'testset/testset\\img840.jpg', 'image_id': 'img840'},
#  {'image_path': 'testset/testset\\img841.jpg', 'image_id': 'img841'},
#  {'image_path': 'testset/testset\\img842.jpg', 'image_id': 'img842'},
#  {'image_path': 'testset/testset\\img843.jpg', 'image_id': 'img843'},
#  {'image_path': 'testset/testset\\img844.jpg', 'image_id': 'img844'},
#  {'image_path': 'testset/testset\\img845.jpg', 'image_id': 'img845'},
#  {'image_path': 'testset/testset\\img846.jpg', 'image_id': 'img846'},
#  {'image_path': 'testset/testset\\img847.jpg', 'image_id': 'img847'},
#  {'image_path': 'testset/testset\\img848.jpg', 'image_id': 'img848'},
#  {'image_path': 'testset/testset\\img849.jpg', 'image_id': 'img849'},
#  {'image_path': 'testset/testset\\img85.jpg', 'image_id': 'img85'},
#  {'image_path': 'testset/testset\\img850.jpg', 'image_id': 'img850'},
#  {'image_path': 'testset/testset\\img851.jpg', 'image_id': 'img851'},
#  {'image_path': 'testset/testset\\img852.jpg', 'image_id': 'img852'},
#  {'image_path': 'testset/testset\\img853.jpg', 'image_id': 'img853'},
#  {'image_path': 'testset/testset\\img854.jpg', 'image_id': 'img854'},
#  {'image_path': 'testset/testset\\img855.jpg', 'image_id': 'img855'},
#  {'image_path': 'testset/testset\\img856.jpg', 'image_id': 'img856'},
#  {'image_path': 'testset/testset\\img857.jpg', 'image_id': 'img857'},
#  {'image_path': 'testset/testset\\img858.jpg', 'image_id': 'img858'},
#  {'image_path': 'testset/testset\\img859.jpg', 'image_id': 'img859'},
#  {'image_path': 'testset/testset\\img86.jpg', 'image_id': 'img86'},
#  {'image_path': 'testset/testset\\img860.jpg', 'image_id': 'img860'},
#  {'image_path': 'testset/testset\\img861.jpg', 'image_id': 'img861'},
#  {'image_path': 'testset/testset\\img862.jpg', 'image_id': 'img862'},
#  {'image_path': 'testset/testset\\img863.jpg', 'image_id': 'img863'},
#  {'image_path': 'testset/testset\\img864.jpg', 'image_id': 'img864'},
#  {'image_path': 'testset/testset\\img865.jpg', 'image_id': 'img865'},
#  {'image_path': 'testset/testset\\img866.jpg', 'image_id': 'img866'},
#  {'image_path': 'testset/testset\\img867.jpg', 'image_id': 'img867'},
#  {'image_path': 'testset/testset\\img868.jpg', 'image_id': 'img868'},
#  {'image_path': 'testset/testset\\img869.jpg', 'image_id': 'img869'},
#  {'image_path': 'testset/testset\\img87.jpg', 'image_id': 'img87'},
#  {'image_path': 'testset/testset\\img870.jpg', 'image_id': 'img870'},
#  {'image_path': 'testset/testset\\img871.jpg', 'image_id': 'img871'},
#  {'image_path': 'testset/testset\\img872.jpg', 'image_id': 'img872'},
#  {'image_path': 'testset/testset\\img873.jpg', 'image_id': 'img873'},
#  {'image_path': 'testset/testset\\img874.jpg', 'image_id': 'img874'},
#  {'image_path': 'testset/testset\\img875.jpg', 'image_id': 'img875'},
#  {'image_path': 'testset/testset\\img876.jpg', 'image_id': 'img876'},
#  {'image_path': 'testset/testset\\img877.jpg', 'image_id': 'img877'},
#  {'image_path': 'testset/testset\\img878.jpg', 'image_id': 'img878'},
#  {'image_path': 'testset/testset\\img879.jpg', 'image_id': 'img879'},
#  {'image_path': 'testset/testset\\img88.jpg', 'image_id': 'img88'},
#  {'image_path': 'testset/testset\\img880.jpg', 'image_id': 'img880'},
#  {'image_path': 'testset/testset\\img881.jpg', 'image_id': 'img881'},
#  {'image_path': 'testset/testset\\img882.jpg', 'image_id': 'img882'},
#  {'image_path': 'testset/testset\\img883.jpg', 'image_id': 'img883'},
#  {'image_path': 'testset/testset\\img884.jpg', 'image_id': 'img884'},
#  {'image_path': 'testset/testset\\img885.jpg', 'image_id': 'img885'},
#  {'image_path': 'testset/testset\\img886.jpg', 'image_id': 'img886'},
#  {'image_path': 'testset/testset\\img887.jpg', 'image_id': 'img887'},
#  {'image_path': 'testset/testset\\img888.jpg', 'image_id': 'img888'},
#  {'image_path': 'testset/testset\\img889.jpg', 'image_id': 'img889'},
#  {'image_path': 'testset/testset\\img89.jpg', 'image_id': 'img89'},
#  {'image_path': 'testset/testset\\img890.jpg', 'image_id': 'img890'},
#  {'image_path': 'testset/testset\\img891.jpg', 'image_id': 'img891'},
#  {'image_path': 'testset/testset\\img892.jpg', 'image_id': 'img892'},
#  {'image_path': 'testset/testset\\img893.jpg', 'image_id': 'img893'},
#  {'image_path': 'testset/testset\\img894.jpg', 'image_id': 'img894'},
#  {'image_path': 'testset/testset\\img895.jpg', 'image_id': 'img895'},
#  {'image_path': 'testset/testset\\img896.jpg', 'image_id': 'img896'},
#  {'image_path': 'testset/testset\\img897.jpg', 'image_id': 'img897'},
#  {'image_path': 'testset/testset\\img898.jpg', 'image_id': 'img898'},
#  {'image_path': 'testset/testset\\img899.jpg', 'image_id': 'img899'},
#  {'image_path': 'testset/testset\\img9.jpg', 'image_id': 'img9'},
#  {'image_path': 'testset/testset\\img90.jpg', 'image_id': 'img90'},
#  {'image_path': 'testset/testset\\img900.jpg', 'image_id': 'img900'},
#  {'image_path': 'testset/testset\\img901.jpg', 'image_id': 'img901'},
#  {'image_path': 'testset/testset\\img902.jpg', 'image_id': 'img902'},
#  {'image_path': 'testset/testset\\img903.jpg', 'image_id': 'img903'},
#  {'image_path': 'testset/testset\\img904.jpg', 'image_id': 'img904'},
#  {'image_path': 'testset/testset\\img905.jpg', 'image_id': 'img905'},
#  {'image_path': 'testset/testset\\img906.jpg', 'image_id': 'img906'},
#  {'image_path': 'testset/testset\\img907.jpg', 'image_id': 'img907'},
#  {'image_path': 'testset/testset\\img908.jpg', 'image_id': 'img908'},
#  {'image_path': 'testset/testset\\img909.jpg', 'image_id': 'img909'},
#  {'image_path': 'testset/testset\\img91.jpg', 'image_id': 'img91'},
#  {'image_path': 'testset/testset\\img910.jpg', 'image_id': 'img910'},
#  {'image_path': 'testset/testset\\img911.jpg', 'image_id': 'img911'},
#  {'image_path': 'testset/testset\\img912.jpg', 'image_id': 'img912'},
#  {'image_path': 'testset/testset\\img913.jpg', 'image_id': 'img913'},
#  {'image_path': 'testset/testset\\img914.jpg', 'image_id': 'img914'},
#  {'image_path': 'testset/testset\\img915.jpg', 'image_id': 'img915'},
#  {'image_path': 'testset/testset\\img916.jpg', 'image_id': 'img916'},
#  {'image_path': 'testset/testset\\img917.jpg', 'image_id': 'img917'},
#  {'image_path': 'testset/testset\\img918.jpg', 'image_id': 'img918'},
#  {'image_path': 'testset/testset\\img919.jpg', 'image_id': 'img919'},
#  {'image_path': 'testset/testset\\img92.jpg', 'image_id': 'img92'},
#  {'image_path': 'testset/testset\\img920.jpg', 'image_id': 'img920'},
#  {'image_path': 'testset/testset\\img921.jpg', 'image_id': 'img921'},
#  {'image_path': 'testset/testset\\img922.jpg', 'image_id': 'img922'},
#  {'image_path': 'testset/testset\\img923.jpg', 'image_id': 'img923'},
#  {'image_path': 'testset/testset\\img924.jpg', 'image_id': 'img924'},
#  {'image_path': 'testset/testset\\img925.jpg', 'image_id': 'img925'},
#  {'image_path': 'testset/testset\\img926.jpg', 'image_id': 'img926'},
#  {'image_path': 'testset/testset\\img927.jpg', 'image_id': 'img927'},
#  {'image_path': 'testset/testset\\img928.jpg', 'image_id': 'img928'},
#  {'image_path': 'testset/testset\\img929.jpg', 'image_id': 'img929'},
#  {'image_path': 'testset/testset\\img93.jpg', 'image_id': 'img93'},
#  {'image_path': 'testset/testset\\img930.jpg', 'image_id': 'img930'},
#  {'image_path': 'testset/testset\\img931.jpg', 'image_id': 'img931'},
#  {'image_path': 'testset/testset\\img932.jpg', 'image_id': 'img932'},
#  {'image_path': 'testset/testset\\img933.jpg', 'image_id': 'img933'},
#  {'image_path': 'testset/testset\\img934.jpg', 'image_id': 'img934'},
#  {'image_path': 'testset/testset\\img935.jpg', 'image_id': 'img935'},
#  {'image_path': 'testset/testset\\img936.jpg', 'image_id': 'img936'},
#  {'image_path': 'testset/testset\\img937.jpg', 'image_id': 'img937'},
#  {'image_path': 'testset/testset\\img938.jpg', 'image_id': 'img938'},
#  {'image_path': 'testset/testset\\img939.jpg', 'image_id': 'img939'},
#  {'image_path': 'testset/testset\\img94.jpg', 'image_id': 'img94'},
#  {'image_path': 'testset/testset\\img940.jpg', 'image_id': 'img940'},
#  {'image_path': 'testset/testset\\img941.jpg', 'image_id': 'img941'},
#  {'image_path': 'testset/testset\\img942.jpg', 'image_id': 'img942'},
#  {'image_path': 'testset/testset\\img943.jpg', 'image_id': 'img943'},
#  {'image_path': 'testset/testset\\img944.jpg', 'image_id': 'img944'},
#  {'image_path': 'testset/testset\\img945.jpg', 'image_id': 'img945'},
#  {'image_path': 'testset/testset\\img946.jpg', 'image_id': 'img946'},
#  {'image_path': 'testset/testset\\img947.jpg', 'image_id': 'img947'},
#  {'image_path': 'testset/testset\\img948.jpg', 'image_id': 'img948'},
#  {'image_path': 'testset/testset\\img949.jpg', 'image_id': 'img949'},
#  {'image_path': 'testset/testset\\img95.jpg', 'image_id': 'img95'},
#  {'image_path': 'testset/testset\\img950.jpg', 'image_id': 'img950'},
#  {'image_path': 'testset/testset\\img951.jpg', 'image_id': 'img951'},
#  {'image_path': 'testset/testset\\img952.jpg', 'image_id': 'img952'},
#  {'image_path': 'testset/testset\\img953.jpg', 'image_id': 'img953'},
#  {'image_path': 'testset/testset\\img954.jpg', 'image_id': 'img954'},
#  {'image_path': 'testset/testset\\img955.jpg', 'image_id': 'img955'},
#  {'image_path': 'testset/testset\\img956.jpg', 'image_id': 'img956'},
#  {'image_path': 'testset/testset\\img957.jpg', 'image_id': 'img957'},
#  {'image_path': 'testset/testset\\img958.jpg', 'image_id': 'img958'},
#  {'image_path': 'testset/testset\\img959.jpg', 'image_id': 'img959'},
#  {'image_path': 'testset/testset\\img96.jpg', 'image_id': 'img96'},
#  {'image_path': 'testset/testset\\img960.jpg', 'image_id': 'img960'},
#  {'image_path': 'testset/testset\\img961.jpg', 'image_id': 'img961'},
#  {'image_path': 'testset/testset\\img962.jpg', 'image_id': 'img962'},
#  {'image_path': 'testset/testset\\img963.jpg', 'image_id': 'img963'},
#  {'image_path': 'testset/testset\\img964.jpg', 'image_id': 'img964'},
#  {'image_path': 'testset/testset\\img965.jpg', 'image_id': 'img965'},
#  {'image_path': 'testset/testset\\img966.jpg', 'image_id': 'img966'},
#  {'image_path': 'testset/testset\\img967.jpg', 'image_id': 'img967'},
#  {'image_path': 'testset/testset\\img968.jpg', 'image_id': 'img968'},
#  {'image_path': 'testset/testset\\img969.jpg', 'image_id': 'img969'},
#  {'image_path': 'testset/testset\\img97.jpg', 'image_id': 'img97'},
#  {'image_path': 'testset/testset\\img970.jpg', 'image_id': 'img970'},
#  {'image_path': 'testset/testset\\img971.jpg', 'image_id': 'img971'},
#  {'image_path': 'testset/testset\\img972.jpg', 'image_id': 'img972'},
#  {'image_path': 'testset/testset\\img973.jpg', 'image_id': 'img973'},
#  {'image_path': 'testset/testset\\img974.jpg', 'image_id': 'img974'},
#  {'image_path': 'testset/testset\\img975.jpg', 'image_id': 'img975'},
#  {'image_path': 'testset/testset\\img976.jpg', 'image_id': 'img976'},
#  {'image_path': 'testset/testset\\img977.jpg', 'image_id': 'img977'},
#  {'image_path': 'testset/testset\\img978.jpg', 'image_id': 'img978'},
#  {'image_path': 'testset/testset\\img979.jpg', 'image_id': 'img979'},
#  {'image_path': 'testset/testset\\img98.jpg', 'image_id': 'img98'},
#  {'image_path': 'testset/testset\\img980.jpg', 'image_id': 'img980'},
#  {'image_path': 'testset/testset\\img981.jpg', 'image_id': 'img981'},
#  {'image_path': 'testset/testset\\img982.jpg', 'image_id': 'img982'},
#  {'image_path': 'testset/testset\\img983.jpg', 'image_id': 'img983'},
#  {'image_path': 'testset/testset\\img984.jpg', 'image_id': 'img984'},
#  {'image_path': 'testset/testset\\img985.jpg', 'image_id': 'img985'},
#  {'image_path': 'testset/testset\\img986.jpg', 'image_id': 'img986'},
#  {'image_path': 'testset/testset\\img987.jpg', 'image_id': 'img987'},
#  {'image_path': 'testset/testset\\img988.jpg', 'image_id': 'img988'},
#  {'image_path': 'testset/testset\\img989.jpg', 'image_id': 'img989'},
#  {'image_path': 'testset/testset\\img99.jpg', 'image_id': 'img99'},
#  {'image_path': 'testset/testset\\img990.jpg', 'image_id': 'img990'}]

# %%
# Разделение тренировочного набора на тренировочную и валидационную части
train_df, val_df = train_test_split(train_data, test_size=0.1, stratify=[d['label'] for d in train_data])

# %%
# Создание объектов Dataset из pandas DataFrame
train_dataset = Dataset.from_pandas(pd.DataFrame(train_df))
val_dataset = Dataset.from_pandas(pd.DataFrame(val_df))
test_df = pd.DataFrame(test_data)
test_dataset = Dataset.from_pandas(test_df)

# %%
train_dataset
# Out:
# Dataset({
#     features: ['image_path', 'label'],
#     num_rows: 18839
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['image_path', 'image_id'],
#     num_rows: 991
# })

# %%
# Загрузка процессора и модели ResNet от Microsoft
processor = AutoImageProcessor.from_pretrained("microsoft/resnet-50")
model = AutoModelForImageClassification.from_pretrained("microsoft/resnet-50", num_labels=num_classes, ignore_mismatched_sizes=True)
# Out:
# Some weights of ResNetForImageClassification were not initialized from the model checkpoint at microsoft/resnet-50 and are newly initialized because the shapes did not match:
# - classifier.1.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([42]) in the model instantiated
# - classifier.1.weight: found shape torch.Size([1000, 2048]) in the checkpoint and torch.Size([42, 2048]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Функция предобработки изображений
def preprocess_function(examples):
    images = [Image.open(image_path).convert("RGB") for image_path in examples["image_path"]]
    inputs = processor(images=images, return_tensors="pt")
    examples["pixel_values"] = inputs["pixel_values"]
    return examples

# %%
# Применение предобработки к тренировочному, валидационному и тестовому датасетам
train_dataset = train_dataset.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/18839 [00:00<?, ? examples/s]

# %%
train_dataset
# Out:
# Dataset({
#     features: ['image_path', 'label', 'pixel_values'],
#     num_rows: 18839
# })

# %%
val_dataset = val_dataset.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/2094 [00:00<?, ? examples/s]

# %%
val_dataset
# Out:
# Dataset({
#     features: ['image_path', 'label', 'pixel_values'],
#     num_rows: 2094
# })

# %%
test_dataset = test_dataset.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/991 [00:00<?, ? examples/s]

# %%
test_dataset
# Out:
# Dataset({
#     features: ['image_path', 'image_id', 'pixel_values'],
#     num_rows: 991
# })

# %%
train_dataset = train_dataset.remove_columns(["image_path"])
val_dataset = val_dataset.remove_columns(["image_path"])
test_dataset = test_dataset.remove_columns(["image_path"])

# %%
train_dataset
# Out:
# Dataset({
#     features: ['label', 'pixel_values'],
#     num_rows: 18839
# })

# %%
# Загрузка метрики F1 из библиотеки evaluate
f1_metric = evaluate.load("f1")

# Функция для расчёта метрик
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = logits.argmax(axis=-1)
    return f1_metric.compute(predictions=predictions, references=labels, average="weighted")

# %%
# Настройка аргументов тренировки с тюнингом гиперпараметров
training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=32,  # Попробуйте различные значения batch_size
    per_device_eval_batch_size=32,
    num_train_epochs=1,  # Попробуйте разные значения для выбора оптимального
    learning_rate=5e-5,  # Начните с этого значения и экспериментируйте
    evaluation_strategy="epoch",
    save_strategy="epoch",
    logging_dir='./logs',
    logging_steps=10,
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    save_total_limit=2,
    remove_unused_columns=False
)

# %%
# Оптимизация использования GPU
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
# Out:
# ResNetForImageClassification(
#   (resnet): ResNetModel(
#     (embedder): ResNetEmbeddings(
#       (embedder): ResNetConvLayer(
#         (convolution): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#         (normalization): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU()
#       )
#       (pooler): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     )
#     (encoder): ResNetEncoder(
#       (stages): ModuleList(
#         (0): ResNetStage(
#           (layers): Sequential(
#             (0): ResNetBottleNeckLayer(
#               (shortcut): ResNetShortCut(
#                 (convolution): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (normalization): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (layer): Sequential(
#                 (0): ResNetConvLayer(
#                   (convolution): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (1): ResNetConvLayer(
#                   (convolution): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (2): ResNetConvLayer(
#                   (convolution): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): Identity()
#                 )
#               )
#               (activation): ReLU()
#             )
#             (1): ResNetBottleNeckLayer(
#               (shortcut): Identity()
#               (layer): Sequential(
#                 (0): ResNetConvLayer(
#                   (convolution): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (1): ResNetConvLayer(
#                   (convolution): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (2): ResNetConvLayer(
#                   (convolution): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): Identity()
#                 )
#               )
#               (activation): ReLU()
#             )
#             (2): ResNetBottleNeckLayer(
#               (shortcut): Identity()
#               (layer): Sequential(
#                 (0): ResNetConvLayer(
#                   (convolution): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (1): ResNetConvLayer(
#                   (convolution): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (2): ResNetConvLayer(
#                   (convolution): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): Identity()
#                 )
#               )
#               (activation): ReLU()
#             )
#           )
#         )
#         (1): ResNetStage(
#           (layers): Sequential(
#             (0): ResNetBottleNeckLayer(
#               (shortcut): ResNetShortCut(
#                 (convolution): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (normalization): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (layer): Sequential(
#                 (0): ResNetConvLayer(
#                   (convolution): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (1): ResNetConvLayer(
#                   (convolution): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (2): ResNetConvLayer(
#                   (convolution): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): Identity()
#                 )
#               )
#               (activation): ReLU()
#             )
#             (1): ResNetBottleNeckLayer(
#               (shortcut): Identity()
#               (layer): Sequential(
#                 (0): ResNetConvLayer(
#                   (convolution): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (1): ResNetConvLayer(
#                   (convolution): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (2): ResNetConvLayer(
#                   (convolution): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): Identity()
#                 )
#               )
#               (activation): ReLU()
#             )
#             (2): ResNetBottleNeckLayer(
#               (shortcut): Identity()
#               (layer): Sequential(
#                 (0): ResNetConvLayer(
#                   (convolution): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (1): ResNetConvLayer(
#                   (convolution): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (2): ResNetConvLayer(
#                   (convolution): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): Identity()
#                 )
#               )
#               (activation): ReLU()
#             )
#             (3): ResNetBottleNeckLayer(
#               (shortcut): Identity()
#               (layer): Sequential(
#                 (0): ResNetConvLayer(
#                   (convolution): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (1): ResNetConvLayer(
#                   (convolution): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (2): ResNetConvLayer(
#                   (convolution): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): Identity()
#                 )
#               )
#               (activation): ReLU()
#             )
#           )
#         )
#         (2): ResNetStage(
#           (layers): Sequential(
#             (0): ResNetBottleNeckLayer(
#               (shortcut): ResNetShortCut(
#                 (convolution): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (normalization): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (layer): Sequential(
#                 (0): ResNetConvLayer(
#                   (convolution): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (1): ResNetConvLayer(
#                   (convolution): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (2): ResNetConvLayer(
#                   (convolution): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): Identity()
#                 )
#               )
#               (activation): ReLU()
#             )
#             (1): ResNetBottleNeckLayer(
#               (shortcut): Identity()
#               (layer): Sequential(
#                 (0): ResNetConvLayer(
#                   (convolution): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (1): ResNetConvLayer(
#                   (convolution): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (2): ResNetConvLayer(
#                   (convolution): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): Identity()
#                 )
#               )
#               (activation): ReLU()
#             )
#             (2): ResNetBottleNeckLayer(
#               (shortcut): Identity()
#               (layer): Sequential(
#                 (0): ResNetConvLayer(
#                   (convolution): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (1): ResNetConvLayer(
#                   (convolution): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (2): ResNetConvLayer(
#                   (convolution): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): Identity()
#                 )
#               )
#               (activation): ReLU()
#             )
#             (3): ResNetBottleNeckLayer(
#               (shortcut): Identity()
#               (layer): Sequential(
#                 (0): ResNetConvLayer(
#                   (convolution): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (1): ResNetConvLayer(
#                   (convolution): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (2): ResNetConvLayer(
#                   (convolution): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): Identity()
#                 )
#               )
#               (activation): ReLU()
#             )
#             (4): ResNetBottleNeckLayer(
#               (shortcut): Identity()
#               (layer): Sequential(
#                 (0): ResNetConvLayer(
#                   (convolution): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (1): ResNetConvLayer(
#                   (convolution): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (2): ResNetConvLayer(
#                   (convolution): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): Identity()
#                 )
#               )
#               (activation): ReLU()
#             )
#             (5): ResNetBottleNeckLayer(
#               (shortcut): Identity()
#               (layer): Sequential(
#                 (0): ResNetConvLayer(
#                   (convolution): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (1): ResNetConvLayer(
#                   (convolution): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (2): ResNetConvLayer(
#                   (convolution): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): Identity()
#                 )
#               )
#               (activation): ReLU()
#             )
#           )
#         )
#         (3): ResNetStage(
#           (layers): Sequential(
#             (0): ResNetBottleNeckLayer(
#               (shortcut): ResNetShortCut(
#                 (convolution): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (normalization): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (layer): Sequential(
#                 (0): ResNetConvLayer(
#                   (convolution): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (1): ResNetConvLayer(
#                   (convolution): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (2): ResNetConvLayer(
#                   (convolution): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): Identity()
#                 )
#               )
#               (activation): ReLU()
#             )
#             (1): ResNetBottleNeckLayer(
#               (shortcut): Identity()
#               (layer): Sequential(
#                 (0): ResNetConvLayer(
#                   (convolution): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (1): ResNetConvLayer(
#                   (convolution): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (2): ResNetConvLayer(
#                   (convolution): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): Identity()
#                 )
#               )
#               (activation): ReLU()
#             )
#             (2): ResNetBottleNeckLayer(
#               (shortcut): Identity()
#               (layer): Sequential(
#                 (0): ResNetConvLayer(
#                   (convolution): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (1): ResNetConvLayer(
#                   (convolution): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): ReLU()
#                 )
#                 (2): ResNetConvLayer(
#                   (convolution): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (normalization): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (activation): Identity()
#                 )
#               )
#               (activation): ReLU()
#             )
#           )
#         )
#       )
#     )
#     (pooler): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=2048, out_features=42, bias=True)
#   )
# )

# %%
# Инициализация Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,  # Используем валидационный набор
    compute_metrics=compute_metrics,
    tokenizer=processor,
)
# Out:
# C:\Users\Max\AppData\Local\Temp\ipykernel_15316\789434975.py:2: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
# Обучение модели
trainer.train()
# Out:
#   0%|          | 0/589 [00:00<?, ?it/s]
# {'loss': 3.6509, 'grad_norm': 1.8901402950286865, 'learning_rate': 4.915110356536503e-05, 'epoch': 0.02}
# {'loss': 3.6383, 'grad_norm': 4.453996658325195, 'learning_rate': 4.8302207130730054e-05, 'epoch': 0.03}
# {'loss': 3.5765, 'grad_norm': 2.43491530418396, 'learning_rate': 4.7453310696095074e-05, 'epoch': 0.05}
# {'loss': 3.5535, 'grad_norm': 4.248633861541748, 'learning_rate': 4.6604414261460106e-05, 'epoch': 0.07}
# {'loss': 3.5344, 'grad_norm': 3.6437602043151855, 'learning_rate': 4.5755517826825125e-05, 'epoch': 0.08}
# {'loss': 3.5025, 'grad_norm': 10.050701141357422, 'learning_rate': 4.490662139219016e-05, 'epoch': 0.1}
# {'loss': 3.4643, 'grad_norm': 2.9539356231689453, 'learning_rate': 4.405772495755518e-05, 'epoch': 0.12}
# {'loss': 3.4341, 'grad_norm': 3.23858642578125, 'learning_rate': 4.320882852292021e-05, 'epoch': 0.14}
# {'loss': 3.3921, 'grad_norm': 4.959323406219482, 'learning_rate': 4.235993208828523e-05, 'epoch': 0.15}
# {'loss': 3.3647, 'grad_norm': 3.0395267009735107, 'learning_rate': 4.1511035653650255e-05, 'epoch': 0.17}
# {'loss': 3.3297, 'grad_norm': 3.4789907932281494, 'learning_rate': 4.066213921901528e-05, 'epoch': 0.19}
# {'loss': 3.2875, 'grad_norm': 2.8728978633880615, 'learning_rate': 3.981324278438031e-05, 'epoch': 0.2}
# {'loss': 3.3076, 'grad_norm': 2.597898483276367, 'learning_rate': 3.896434634974533e-05, 'epoch': 0.22}
# {'loss': 3.2962, 'grad_norm': 3.79917573928833, 'learning_rate': 3.811544991511036e-05, 'epoch': 0.24}
# {'loss': 3.2546, 'grad_norm': 3.6774957180023193, 'learning_rate': 3.7266553480475385e-05, 'epoch': 0.25}
# {'loss': 3.2253, 'grad_norm': 4.663549423217773, 'learning_rate': 3.641765704584041e-05, 'epoch': 0.27}
# {'loss': 3.2311, 'grad_norm': 2.7073211669921875, 'learning_rate': 3.556876061120544e-05, 'epoch': 0.29}
# {'loss': 3.1835, 'grad_norm': 4.599233627319336, 'learning_rate': 3.471986417657046e-05, 'epoch': 0.31}
# {'loss': 3.1174, 'grad_norm': 2.754147529602051, 'learning_rate': 3.387096774193548e-05, 'epoch': 0.32}
# {'loss': 3.1671, 'grad_norm': 3.2970921993255615, 'learning_rate': 3.3022071307300515e-05, 'epoch': 0.34}
# {'loss': 3.1222, 'grad_norm': 3.5537850856781006, 'learning_rate': 3.2173174872665534e-05, 'epoch': 0.36}
# {'loss': 3.1442, 'grad_norm': 5.187653064727783, 'learning_rate': 3.132427843803056e-05, 'epoch': 0.37}
# {'loss': 3.1143, 'grad_norm': 4.075695991516113, 'learning_rate': 3.0475382003395586e-05, 'epoch': 0.39}
# {'loss': 3.1165, 'grad_norm': 3.903026580810547, 'learning_rate': 2.9626485568760615e-05, 'epoch': 0.41}
# {'loss': 3.0592, 'grad_norm': 2.6764607429504395, 'learning_rate': 2.8777589134125638e-05, 'epoch': 0.42}
# {'loss': 3.1005, 'grad_norm': 3.508002758026123, 'learning_rate': 2.7928692699490667e-05, 'epoch': 0.44}
# {'loss': 3.0109, 'grad_norm': 2.732834815979004, 'learning_rate': 2.707979626485569e-05, 'epoch': 0.46}
# {'loss': 3.0786, 'grad_norm': 4.933979034423828, 'learning_rate': 2.6230899830220713e-05, 'epoch': 0.48}
# {'loss': 3.0701, 'grad_norm': 3.171410322189331, 'learning_rate': 2.5382003395585742e-05, 'epoch': 0.49}
# {'loss': 3.052, 'grad_norm': 3.233120918273926, 'learning_rate': 2.4533106960950768e-05, 'epoch': 0.51}
# {'loss': 3.0454, 'grad_norm': 3.523446798324585, 'learning_rate': 2.368421052631579e-05, 'epoch': 0.53}
# {'loss': 3.0346, 'grad_norm': 3.391662120819092, 'learning_rate': 2.2835314091680816e-05, 'epoch': 0.54}
# {'loss': 3.0118, 'grad_norm': 2.3343923091888428, 'learning_rate': 2.1986417657045842e-05, 'epoch': 0.56}
# {'loss': 2.9988, 'grad_norm': 3.7129669189453125, 'learning_rate': 2.1137521222410865e-05, 'epoch': 0.58}
# {'loss': 3.0116, 'grad_norm': 5.616011142730713, 'learning_rate': 2.028862478777589e-05, 'epoch': 0.59}
# {'loss': 3.02, 'grad_norm': 4.4569172859191895, 'learning_rate': 1.9439728353140917e-05, 'epoch': 0.61}
# {'loss': 3.0105, 'grad_norm': 2.9657416343688965, 'learning_rate': 1.8590831918505943e-05, 'epoch': 0.63}
# {'loss': 2.984, 'grad_norm': 5.320135116577148, 'learning_rate': 1.774193548387097e-05, 'epoch': 0.65}
# {'loss': 2.9992, 'grad_norm': 4.24544620513916, 'learning_rate': 1.6893039049235995e-05, 'epoch': 0.66}
# {'loss': 2.9891, 'grad_norm': 3.8531062602996826, 'learning_rate': 1.6044142614601017e-05, 'epoch': 0.68}
# {'loss': 2.978, 'grad_norm': 3.7584402561187744, 'learning_rate': 1.5195246179966043e-05, 'epoch': 0.7}
# {'loss': 2.9827, 'grad_norm': 4.827934265136719, 'learning_rate': 1.434634974533107e-05, 'epoch': 0.71}
# {'loss': 2.9572, 'grad_norm': 3.1169700622558594, 'learning_rate': 1.3497453310696095e-05, 'epoch': 0.73}
# {'loss': 2.9863, 'grad_norm': 3.1122336387634277, 'learning_rate': 1.2648556876061121e-05, 'epoch': 0.75}
# {'loss': 2.9632, 'grad_norm': 3.639434337615967, 'learning_rate': 1.1799660441426147e-05, 'epoch': 0.76}
# {'loss': 2.9517, 'grad_norm': 3.4805212020874023, 'learning_rate': 1.0950764006791173e-05, 'epoch': 0.78}
# {'loss': 2.9872, 'grad_norm': 4.665362358093262, 'learning_rate': 1.0101867572156197e-05, 'epoch': 0.8}
# {'loss': 2.9455, 'grad_norm': 2.9849853515625, 'learning_rate': 9.252971137521223e-06, 'epoch': 0.81}
# {'loss': 2.9651, 'grad_norm': 3.4526426792144775, 'learning_rate': 8.404074702886248e-06, 'epoch': 0.83}
# {'loss': 2.9139, 'grad_norm': 3.4784297943115234, 'learning_rate': 7.5551782682512745e-06, 'epoch': 0.85}
# {'loss': 2.9699, 'grad_norm': 2.392163038253784, 'learning_rate': 6.706281833616299e-06, 'epoch': 0.87}
# {'loss': 2.876, 'grad_norm': 6.24363374710083, 'learning_rate': 5.857385398981325e-06, 'epoch': 0.88}
# {'loss': 2.8257, 'grad_norm': 3.311333656311035, 'learning_rate': 5.00848896434635e-06, 'epoch': 0.9}
# {'loss': 2.9543, 'grad_norm': 3.7300872802734375, 'learning_rate': 4.159592529711375e-06, 'epoch': 0.92}
# {'loss': 2.9628, 'grad_norm': 3.3252735137939453, 'learning_rate': 3.310696095076401e-06, 'epoch': 0.93}
# {'loss': 2.896, 'grad_norm': 2.7197206020355225, 'learning_rate': 2.461799660441426e-06, 'epoch': 0.95}
# {'loss': 2.9352, 'grad_norm': 4.092561721801758, 'learning_rate': 1.6129032258064516e-06, 'epoch': 0.97}
# {'loss': 2.9168, 'grad_norm': 4.897315979003906, 'learning_rate': 7.640067911714771e-07, 'epoch': 0.98}
#   0%|          | 0/66 [00:00<?, ?it/s]
# {'eval_loss': 2.925139904022217, 'eval_f1': 0.03691579141028085, 'eval_runtime': 151.7695, 'eval_samples_per_second': 13.797, 'eval_steps_per_second': 0.435, 'epoch': 1.0}
# {'train_runtime': 1597.8009, 'train_samples_per_second': 11.791, 'train_steps_per_second': 0.369, 'train_loss': 3.1259124412601387, 'epoch': 1.0}
# TrainOutput(global_step=589, training_loss=3.1259124412601387, metrics={'train_runtime': 1597.8009, 'train_samples_per_second': 11.791, 'train_steps_per_second': 0.369, 'total_flos': 4.014482967058637e+17, 'train_loss': 3.1259124412601387, 'epoch': 1.0})

# %%
# Предсказания на тестовом наборе
predictions = trainer.predict(test_dataset)
predicted_labels = predictions.predictions.argmax(axis=-1)
# Out:
#   0%|          | 0/31 [00:00<?, ?it/s]

# %%
predictions
# Out:
# PredictionOutput(predictions=array([[ 0.46198332, -1.5716109 , -0.08818911, ..., -1.5768465 ,
#         -1.9783835 , -0.865121  ],
#        [ 0.18649301, -0.99858266,  0.0463847 , ..., -0.8866917 ,
#         -1.2029325 , -0.47244984],
#        [ 0.5569199 , -2.226527  ,  0.10149281, ..., -2.3168194 ,
#         -2.7985673 , -1.2513454 ],
#        ...,
#        [ 0.45123282, -1.2973677 ,  0.13329583, ..., -1.2690095 ,
#         -1.659847  , -0.79832125],
#        [ 0.25707057, -1.2821813 ,  0.06671086, ..., -1.1640714 ,
#         -1.2387038 , -0.6421496 ],
#        [ 0.39317867, -1.1985978 ,  0.09774639, ..., -1.1788081 ,
#         -1.3793693 , -0.6515255 ]], dtype=float32), label_ids=None, metrics={'test_runtime': 69.5207, 'test_samples_per_second': 14.255, 'test_steps_per_second': 0.446})

# %%
predicted_labels
# Out:
# array([15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 27, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 20, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 27, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 20, 15, 15, 15, 27, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 20, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15,  6, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 20, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 17, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 20, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 20, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 20, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 20, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 20, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 27, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 20, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 27, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 27, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 27, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 27, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 27, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 27, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 20,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15], dtype=int64)

# %%
predicted_labels
# Out:
# array([15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 27, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 20, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 27, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 20, 15, 15, 15, 27, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 20, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15,  6, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 20, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 17, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 20, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 20, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 20, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 20, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 20, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 27, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 20, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 27, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 27, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 27, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 27, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 27, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 27, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 20,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15, 15,
#        15, 15, 15, 15, 15], dtype=int64)

# %%
# Преобразование предсказанных меток в имена классов
label_to_character = {v: k for k, v in character_labels.items()}

# %%
label_to_character
# Out:
# {0: 'abraham_grampa_simpson',
#  1: 'agnes_skinner',
#  2: 'apu_nahasapeemapetilon',
#  3: 'barney_gumble',
#  4: 'bart_simpson',
#  5: 'carl_carlson',
#  6: 'charles_montgomery_burns',
#  7: 'chief_wiggum',
#  8: 'cletus_spuckler',
#  9: 'comic_book_guy',
#  10: 'disco_stu',
#  11: 'edna_krabappel',
#  12: 'fat_tony',
#  13: 'gil',
#  14: 'groundskeeper_willie',
#  15: 'homer_simpson',
#  16: 'kent_brockman',
#  17: 'krusty_the_clown',
#  18: 'lenny_leonard',
#  19: 'lionel_hutz',
#  20: 'lisa_simpson',
#  21: 'maggie_simpson',
#  22: 'marge_simpson',
#  23: 'martin_prince',
#  24: 'mayor_quimby',
#  25: 'milhouse_van_houten',
#  26: 'miss_hoover',
#  27: 'moe_szyslak',
#  28: 'ned_flanders',
#  29: 'nelson_muntz',
#  30: 'otto_mann',
#  31: 'patty_bouvier',
#  32: 'principal_skinner',
#  33: 'professor_john_frink',
#  34: 'rainier_wolfcastle',
#  35: 'ralph_wiggum',
#  36: 'selma_bouvier',
#  37: 'sideshow_bob',
#  38: 'sideshow_mel',
#  39: 'snake_jailbird',
#  40: 'troy_mcclure',
#  41: 'waylon_smithers'}

# %%
predicted_characters = [label_to_character[label] for label in predicted_labels]
test_img_ids = test_df["image_id"].tolist()

# %%
predicted_characters
# Out:
# ['homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'moe_szyslak',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'lisa_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'moe_szyslak',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'lisa_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'moe_szyslak',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'lisa_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'charles_montgomery_burns',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'lisa_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'krusty_the_clown',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'lisa_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'lisa_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'lisa_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'lisa_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'lisa_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'moe_szyslak',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'lisa_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'moe_szyslak',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'moe_szyslak',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'moe_szyslak',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'moe_szyslak',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'moe_szyslak',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'moe_szyslak',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'lisa_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson',
#  'homer_simpson']

# %%
test_img_ids
# Out:
# ['img0',
#  'img1',
#  'img10',
#  'img100',
#  'img101',
#  'img102',
#  'img103',
#  'img104',
#  'img105',
#  'img106',
#  'img107',
#  'img108',
#  'img109',
#  'img11',
#  'img110',
#  'img111',
#  'img112',
#  'img113',
#  'img114',
#  'img115',
#  'img116',
#  'img117',
#  'img118',
#  'img119',
#  'img12',
#  'img120',
#  'img121',
#  'img122',
#  'img123',
#  'img124',
#  'img125',
#  'img126',
#  'img127',
#  'img128',
#  'img129',
#  'img13',
#  'img130',
#  'img131',
#  'img132',
#  'img133',
#  'img134',
#  'img135',
#  'img136',
#  'img137',
#  'img138',
#  'img139',
#  'img14',
#  'img140',
#  'img141',
#  'img142',
#  'img143',
#  'img144',
#  'img145',
#  'img146',
#  'img147',
#  'img148',
#  'img149',
#  'img15',
#  'img150',
#  'img151',
#  'img152',
#  'img153',
#  'img154',
#  'img155',
#  'img156',
#  'img157',
#  'img158',
#  'img159',
#  'img16',
#  'img160',
#  'img161',
#  'img162',
#  'img163',
#  'img164',
#  'img165',
#  'img166',
#  'img167',
#  'img168',
#  'img169',
#  'img17',
#  'img170',
#  'img171',
#  'img172',
#  'img173',
#  'img174',
#  'img175',
#  'img176',
#  'img177',
#  'img178',
#  'img179',
#  'img18',
#  'img180',
#  'img181',
#  'img182',
#  'img183',
#  'img184',
#  'img185',
#  'img186',
#  'img187',
#  'img188',
#  'img189',
#  'img19',
#  'img190',
#  'img191',
#  'img192',
#  'img193',
#  'img194',
#  'img195',
#  'img196',
#  'img197',
#  'img198',
#  'img199',
#  'img2',
#  'img20',
#  'img200',
#  'img201',
#  'img202',
#  'img203',
#  'img204',
#  'img205',
#  'img206',
#  'img207',
#  'img208',
#  'img209',
#  'img21',
#  'img210',
#  'img211',
#  'img212',
#  'img213',
#  'img214',
#  'img215',
#  'img216',
#  'img217',
#  'img218',
#  'img219',
#  'img22',
#  'img220',
#  'img221',
#  'img222',
#  'img223',
#  'img224',
#  'img225',
#  'img226',
#  'img227',
#  'img228',
#  'img229',
#  'img23',
#  'img230',
#  'img231',
#  'img232',
#  'img233',
#  'img234',
#  'img235',
#  'img236',
#  'img237',
#  'img238',
#  'img239',
#  'img24',
#  'img240',
#  'img241',
#  'img242',
#  'img243',
#  'img244',
#  'img245',
#  'img246',
#  'img247',
#  'img248',
#  'img249',
#  'img25',
#  'img250',
#  'img251',
#  'img252',
#  'img253',
#  'img254',
#  'img255',
#  'img256',
#  'img257',
#  'img258',
#  'img259',
#  'img26',
#  'img260',
#  'img261',
#  'img262',
#  'img263',
#  'img264',
#  'img265',
#  'img266',
#  'img267',
#  'img268',
#  'img269',
#  'img27',
#  'img270',
#  'img271',
#  'img272',
#  'img273',
#  'img274',
#  'img275',
#  'img276',
#  'img277',
#  'img278',
#  'img279',
#  'img28',
#  'img280',
#  'img281',
#  'img282',
#  'img283',
#  'img284',
#  'img285',
#  'img286',
#  'img287',
#  'img288',
#  'img289',
#  'img29',
#  'img290',
#  'img291',
#  'img292',
#  'img293',
#  'img294',
#  'img295',
#  'img296',
#  'img297',
#  'img298',
#  'img299',
#  'img3',
#  'img30',
#  'img300',
#  'img301',
#  'img302',
#  'img303',
#  'img304',
#  'img305',
#  'img306',
#  'img307',
#  'img308',
#  'img309',
#  'img31',
#  'img310',
#  'img311',
#  'img312',
#  'img313',
#  'img314',
#  'img315',
#  'img316',
#  'img317',
#  'img318',
#  'img319',
#  'img32',
#  'img320',
#  'img321',
#  'img322',
#  'img323',
#  'img324',
#  'img325',
#  'img326',
#  'img327',
#  'img328',
#  'img329',
#  'img33',
#  'img330',
#  'img331',
#  'img332',
#  'img333',
#  'img334',
#  'img335',
#  'img336',
#  'img337',
#  'img338',
#  'img339',
#  'img34',
#  'img340',
#  'img341',
#  'img342',
#  'img343',
#  'img344',
#  'img345',
#  'img346',
#  'img347',
#  'img348',
#  'img349',
#  'img35',
#  'img350',
#  'img351',
#  'img352',
#  'img353',
#  'img354',
#  'img355',
#  'img356',
#  'img357',
#  'img358',
#  'img359',
#  'img36',
#  'img360',
#  'img361',
#  'img362',
#  'img363',
#  'img364',
#  'img365',
#  'img366',
#  'img367',
#  'img368',
#  'img369',
#  'img37',
#  'img370',
#  'img371',
#  'img372',
#  'img373',
#  'img374',
#  'img375',
#  'img376',
#  'img377',
#  'img378',
#  'img379',
#  'img38',
#  'img380',
#  'img381',
#  'img382',
#  'img383',
#  'img384',
#  'img385',
#  'img386',
#  'img387',
#  'img388',
#  'img389',
#  'img39',
#  'img390',
#  'img391',
#  'img392',
#  'img393',
#  'img394',
#  'img395',
#  'img396',
#  'img397',
#  'img398',
#  'img399',
#  'img4',
#  'img40',
#  'img400',
#  'img401',
#  'img402',
#  'img403',
#  'img404',
#  'img405',
#  'img406',
#  'img407',
#  'img408',
#  'img409',
#  'img41',
#  'img410',
#  'img411',
#  'img412',
#  'img413',
#  'img414',
#  'img415',
#  'img416',
#  'img417',
#  'img418',
#  'img419',
#  'img42',
#  'img420',
#  'img421',
#  'img422',
#  'img423',
#  'img424',
#  'img425',
#  'img426',
#  'img427',
#  'img428',
#  'img429',
#  'img43',
#  'img430',
#  'img431',
#  'img432',
#  'img433',
#  'img434',
#  'img435',
#  'img436',
#  'img437',
#  'img438',
#  'img439',
#  'img44',
#  'img440',
#  'img441',
#  'img442',
#  'img443',
#  'img444',
#  'img445',
#  'img446',
#  'img447',
#  'img448',
#  'img449',
#  'img45',
#  'img450',
#  'img451',
#  'img452',
#  'img453',
#  'img454',
#  'img455',
#  'img456',
#  'img457',
#  'img458',
#  'img459',
#  'img46',
#  'img460',
#  'img461',
#  'img462',
#  'img463',
#  'img464',
#  'img465',
#  'img466',
#  'img467',
#  'img468',
#  'img469',
#  'img47',
#  'img470',
#  'img471',
#  'img472',
#  'img473',
#  'img474',
#  'img475',
#  'img476',
#  'img477',
#  'img478',
#  'img479',
#  'img48',
#  'img480',
#  'img481',
#  'img482',
#  'img483',
#  'img484',
#  'img485',
#  'img486',
#  'img487',
#  'img488',
#  'img489',
#  'img49',
#  'img490',
#  'img491',
#  'img492',
#  'img493',
#  'img494',
#  'img495',
#  'img496',
#  'img497',
#  'img498',
#  'img499',
#  'img5',
#  'img50',
#  'img500',
#  'img501',
#  'img502',
#  'img503',
#  'img504',
#  'img505',
#  'img506',
#  'img507',
#  'img508',
#  'img509',
#  'img51',
#  'img510',
#  'img511',
#  'img512',
#  'img513',
#  'img514',
#  'img515',
#  'img516',
#  'img517',
#  'img518',
#  'img519',
#  'img52',
#  'img520',
#  'img521',
#  'img522',
#  'img523',
#  'img524',
#  'img525',
#  'img526',
#  'img527',
#  'img528',
#  'img529',
#  'img53',
#  'img530',
#  'img531',
#  'img532',
#  'img533',
#  'img534',
#  'img535',
#  'img536',
#  'img537',
#  'img538',
#  'img539',
#  'img54',
#  'img540',
#  'img541',
#  'img542',
#  'img543',
#  'img544',
#  'img545',
#  'img546',
#  'img547',
#  'img548',
#  'img549',
#  'img55',
#  'img550',
#  'img551',
#  'img552',
#  'img553',
#  'img554',
#  'img555',
#  'img556',
#  'img557',
#  'img558',
#  'img559',
#  'img56',
#  'img560',
#  'img561',
#  'img562',
#  'img563',
#  'img564',
#  'img565',
#  'img566',
#  'img567',
#  'img568',
#  'img569',
#  'img57',
#  'img570',
#  'img571',
#  'img572',
#  'img573',
#  'img574',
#  'img575',
#  'img576',
#  'img577',
#  'img578',
#  'img579',
#  'img58',
#  'img580',
#  'img581',
#  'img582',
#  'img583',
#  'img584',
#  'img585',
#  'img586',
#  'img587',
#  'img588',
#  'img589',
#  'img59',
#  'img590',
#  'img591',
#  'img592',
#  'img593',
#  'img594',
#  'img595',
#  'img596',
#  'img597',
#  'img598',
#  'img599',
#  'img6',
#  'img60',
#  'img600',
#  'img601',
#  'img602',
#  'img603',
#  'img604',
#  'img605',
#  'img606',
#  'img607',
#  'img608',
#  'img609',
#  'img61',
#  'img610',
#  'img611',
#  'img612',
#  'img613',
#  'img614',
#  'img615',
#  'img616',
#  'img617',
#  'img618',
#  'img619',
#  'img62',
#  'img620',
#  'img621',
#  'img622',
#  'img623',
#  'img624',
#  'img625',
#  'img626',
#  'img627',
#  'img628',
#  'img629',
#  'img63',
#  'img630',
#  'img631',
#  'img632',
#  'img633',
#  'img634',
#  'img635',
#  'img636',
#  'img637',
#  'img638',
#  'img639',
#  'img64',
#  'img640',
#  'img641',
#  'img642',
#  'img643',
#  'img644',
#  'img645',
#  'img646',
#  'img647',
#  'img648',
#  'img649',
#  'img65',
#  'img650',
#  'img651',
#  'img652',
#  'img653',
#  'img654',
#  'img655',
#  'img656',
#  'img657',
#  'img658',
#  'img659',
#  'img66',
#  'img660',
#  'img661',
#  'img662',
#  'img663',
#  'img664',
#  'img665',
#  'img666',
#  'img667',
#  'img668',
#  'img669',
#  'img67',
#  'img670',
#  'img671',
#  'img672',
#  'img673',
#  'img674',
#  'img675',
#  'img676',
#  'img677',
#  'img678',
#  'img679',
#  'img68',
#  'img680',
#  'img681',
#  'img682',
#  'img683',
#  'img684',
#  'img685',
#  'img686',
#  'img687',
#  'img688',
#  'img689',
#  'img69',
#  'img690',
#  'img691',
#  'img692',
#  'img693',
#  'img694',
#  'img695',
#  'img696',
#  'img697',
#  'img698',
#  'img699',
#  'img7',
#  'img70',
#  'img700',
#  'img701',
#  'img702',
#  'img703',
#  'img704',
#  'img705',
#  'img706',
#  'img707',
#  'img708',
#  'img709',
#  'img71',
#  'img710',
#  'img711',
#  'img712',
#  'img713',
#  'img714',
#  'img715',
#  'img716',
#  'img717',
#  'img718',
#  'img719',
#  'img72',
#  'img720',
#  'img721',
#  'img722',
#  'img723',
#  'img724',
#  'img725',
#  'img726',
#  'img727',
#  'img728',
#  'img729',
#  'img73',
#  'img730',
#  'img731',
#  'img732',
#  'img733',
#  'img734',
#  'img735',
#  'img736',
#  'img737',
#  'img738',
#  'img739',
#  'img74',
#  'img740',
#  'img741',
#  'img742',
#  'img743',
#  'img744',
#  'img745',
#  'img746',
#  'img747',
#  'img748',
#  'img749',
#  'img75',
#  'img750',
#  'img751',
#  'img752',
#  'img753',
#  'img754',
#  'img755',
#  'img756',
#  'img757',
#  'img758',
#  'img759',
#  'img76',
#  'img760',
#  'img761',
#  'img762',
#  'img763',
#  'img764',
#  'img765',
#  'img766',
#  'img767',
#  'img768',
#  'img769',
#  'img77',
#  'img770',
#  'img771',
#  'img772',
#  'img773',
#  'img774',
#  'img775',
#  'img776',
#  'img777',
#  'img778',
#  'img779',
#  'img78',
#  'img780',
#  'img781',
#  'img782',
#  'img783',
#  'img784',
#  'img785',
#  'img786',
#  'img787',
#  'img788',
#  'img789',
#  'img79',
#  'img790',
#  'img791',
#  'img792',
#  'img793',
#  'img794',
#  'img795',
#  'img796',
#  'img797',
#  'img798',
#  'img799',
#  'img8',
#  'img80',
#  'img800',
#  'img801',
#  'img802',
#  'img803',
#  'img804',
#  'img805',
#  'img806',
#  'img807',
#  'img808',
#  'img809',
#  'img81',
#  'img810',
#  'img811',
#  'img812',
#  'img813',
#  'img814',
#  'img815',
#  'img816',
#  'img817',
#  'img818',
#  'img819',
#  'img82',
#  'img820',
#  'img821',
#  'img822',
#  'img823',
#  'img824',
#  'img825',
#  'img826',
#  'img827',
#  'img828',
#  'img829',
#  'img83',
#  'img830',
#  'img831',
#  'img832',
#  'img833',
#  'img834',
#  'img835',
#  'img836',
#  'img837',
#  'img838',
#  'img839',
#  'img84',
#  'img840',
#  'img841',
#  'img842',
#  'img843',
#  'img844',
#  'img845',
#  'img846',
#  'img847',
#  'img848',
#  'img849',
#  'img85',
#  'img850',
#  'img851',
#  'img852',
#  'img853',
#  'img854',
#  'img855',
#  'img856',
#  'img857',
#  'img858',
#  'img859',
#  'img86',
#  'img860',
#  'img861',
#  'img862',
#  'img863',
#  'img864',
#  'img865',
#  'img866',
#  'img867',
#  'img868',
#  'img869',
#  'img87',
#  'img870',
#  'img871',
#  'img872',
#  'img873',
#  'img874',
#  'img875',
#  'img876',
#  'img877',
#  'img878',
#  'img879',
#  'img88',
#  'img880',
#  'img881',
#  'img882',
#  'img883',
#  'img884',
#  'img885',
#  'img886',
#  'img887',
#  'img888',
#  'img889',
#  'img89',
#  'img890',
#  'img891',
#  'img892',
#  'img893',
#  'img894',
#  'img895',
#  'img896',
#  'img897',
#  'img898',
#  'img899',
#  'img9',
#  'img90',
#  'img900',
#  'img901',
#  'img902',
#  'img903',
#  'img904',
#  'img905',
#  'img906',
#  'img907',
#  'img908',
#  'img909',
#  'img91',
#  'img910',
#  'img911',
#  'img912',
#  'img913',
#  'img914',
#  'img915',
#  'img916',
#  'img917',
#  'img918',
#  'img919',
#  'img92',
#  'img920',
#  'img921',
#  'img922',
#  'img923',
#  'img924',
#  'img925',
#  'img926',
#  'img927',
#  'img928',
#  'img929',
#  'img93',
#  'img930',
#  'img931',
#  'img932',
#  'img933',
#  'img934',
#  'img935',
#  'img936',
#  'img937',
#  'img938',
#  'img939',
#  'img94',
#  'img940',
#  'img941',
#  'img942',
#  'img943',
#  'img944',
#  'img945',
#  'img946',
#  'img947',
#  'img948',
#  'img949',
#  'img95',
#  'img950',
#  'img951',
#  'img952',
#  'img953',
#  'img954',
#  'img955',
#  'img956',
#  'img957',
#  'img958',
#  'img959',
#  'img96',
#  'img960',
#  'img961',
#  'img962',
#  'img963',
#  'img964',
#  'img965',
#  'img966',
#  'img967',
#  'img968',
#  'img969',
#  'img97',
#  'img970',
#  'img971',
#  'img972',
#  'img973',
#  'img974',
#  'img975',
#  'img976',
#  'img977',
#  'img978',
#  'img979',
#  'img98',
#  'img980',
#  'img981',
#  'img982',
#  'img983',
#  'img984',
#  'img985',
#  'img986',
#  'img987',
#  'img988',
#  'img989',
#  'img99',
#  'img990']

# %%
# Создание файла для отправки
submission= pd.DataFrame({"Id": test_img_ids, "Expected": predicted_characters})

# %%
submission
# Out:
#          Id       Expected
# 0      img0  homer_simpson
# 1      img1  homer_simpson
# 2     img10  homer_simpson
# 3    img100  homer_simpson
# 4    img101  homer_simpson
# ..      ...            ...
# 986  img987  homer_simpson
# 987  img988  homer_simpson
# 988  img989  homer_simpson
# 989   img99  homer_simpson
# 990  img990  homer_simpson
#
# [991 rows x 2 columns]

# %%
submission['Id'] = submission['Id'].apply(lambda x: f"{x}.jpg" if not x.endswith('.jpg') else x)

# %%
submission
# Out:
#              Id       Expected
# 0      img0.jpg  homer_simpson
# 1      img1.jpg  homer_simpson
# 2     img10.jpg  homer_simpson
# 3    img100.jpg  homer_simpson
# 4    img101.jpg  homer_simpson
# ..          ...            ...
# 986  img987.jpg  homer_simpson
# 987  img988.jpg  homer_simpson
# 988  img989.jpg  homer_simpson
# 989   img99.jpg  homer_simpson
# 990  img990.jpg  homer_simpson
#
# [991 rows x 2 columns]

# %%
submission.to_csv("submission.csv", index=False)
